# %%
import pandas as pd
import os
import numpy as np
import h5py

# %%
coop_dirs = ['PairedTestingSessions']
root = '/gpfs/radev/pi/saxena/aj764'

# %%
df = pd.DataFrame(columns = ['dir', 'session', 'video', 'color type', 'color pair', 'tracked', 'error', 'lever', 'mag', 'event id', 'fiber pho', 'coop thresh', 'animal id', 'cohort', 'visual', 'vehicle', 'familiar'])

for coop in coop_dirs:
    sessions = os.listdir(f'{root}/{coop}')
    for sesh in sessions:
        if os.path.exists(f'{root}/{coop}/{sesh}/Videos/'):
            vids = os.listdir(f'{root}/{coop}/{sesh}/Videos/')
            vids = [x for x in vids if '.mp4' in x]
            for vid in vids:
                if 'Comp' or 'Ineq' in coop:
                    try:
                        name = vid.split('.')[0]
                        date = name.split('_')[0]
                        color_type = 'dyed' if (int(date[-2:]) == 24 and int(date[:2]) < 11) else 'collar'
                        color = name.split('_')
                        animal_id = [x for x in color if (len(x) == 13 or len(x) == 14)][0]
                        color = animal_id.split('-')
                        color = [color[0][-1], color[1][-1]]
                        color_pair = ''
                        if 'R' in color:
                            color_pair += 'R'
                        if 'G' in color:
                            color_pair += 'G'
                        if 'Y' in color:
                            color_pair += 'Y'
                        if 'B' in color:
                            color_pair += 'B'
                        preds = os.path.exists(f'{root}/{coop}/{sesh}/Tracking/slp/{name}.predictions.slp')
                        if preds:
                            with h5py.File(f'{root}/{coop}/{sesh}/Tracking/h5_uncorrected/{name}.predictions.h5','r') as f:
                                locations = f["tracks"][:].T
                            error = np.sum(np.isnan(locations)) / np.prod(locations.shape)
                        else:
                            error = np.nan
                        lever = os.path.exists (f'{root}/{coop}/{sesh}/Behavioral/processed/lever/{name}_lever.csv')
                        mag = os.path.exists(f'{root}/{coop}/{sesh}/Behavioral/processed/mag/{name}_mag.csv')
                        if lever:
                            levs = pd.read_csv(f'{root}/{coop}/{sesh}/Behavioral/processed/lever/{name}_lever.csv')
                            event_id = 'RatID' in levs.columns.tolist()
                            coop_thresh = np.average(levs['CoopTimeLimit'])
                        else:
                            event_id = False
                            coop_thresh = np.nan
                        neuronal = os.path.exists(f'{root}/{coop}/{sesh}/Neuronal/{name}.mat')
                        cohort = animal_id.split('-')[0][:2]
                        visual = 'opaque' if 'opaque' in sesh else ('translucent' if 'translucent' in sesh else 'transparent')
                        pos_vehs = ['CNO', 'VEH', 'DCZ', 'SAL', 'MDMA']
                        vehicle = [x for x in pos_vehs if x in sesh]
                        if len(vehicle) == 1:
                            vehicle = vehicle[0]
                        else:
                            vehicle = np.nan
                        familiar = 'unfamiliar' if (animal_id.split('-')[0][:-1] != animal_id.split('-')[1][:-1] and cohort == 'KL') else 'familiar'
                        if cohort == 'KM' or cohort == 'KF':
                            familiar = 'unsure'
                        df.loc[len(df)] = [coop, sesh, name, color_type, color_pair, preds, error, lever, mag, event_id, neuronal, coop_thresh, animal_id, cohort, visual, vehicle, familiar]
                    except Exception as e:
                        print(e, coop, sesh, vid)
# Out:
# list index out of range PairedTestingSessions 022125_PairedTesting_TimeOut_DREADD_KM010-KM015G_DCZ-DCZ 022125_Cam1_TrNum4_Yoked_KM010Y_DCZ.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/022125_PairedTesting_TimeOut_DREADD_KM010-KM015G_DCZ-DCZ/Tracking/h5_uncorrected/022125_Cam1_TrNum5_Comp_KM010B-KM010Y_DCZ-DCZ.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 022125_PairedTesting_TimeOut_DREADD_KM010-KM015G_DCZ-DCZ 022125_Cam1_TrNum5_Comp_KM010B-KM010Y_DCZ-DCZ.mp4
# list index out of range PairedTestingSessions 022125_PairedTesting_TimeOut_DREADD_KM010-KM015G_DCZ-DCZ 022125_Cam1_TrNum3_IS_KM015G_SAL.mp4
# list index out of range PairedTestingSessions 022125_PairedTesting_TimeOut_DREADD_KM010-KM015G_DCZ-DCZ 022125_Cam1_TrNum1_IS_KM010Y_DCZ.mp4
# list index out of range PairedTestingSessions 022125_PairedTesting_TimeOut_DREADD_KM010-KM015G_DCZ-DCZ 022125_Cam1_TrNum6_Yoked_KM010B_DCZ.mp4
# list index out of range PairedTestingSessions 022125_PairedTesting_TimeOut_DREADD_KM010-KM015G_DCZ-DCZ 022125_Cam1_TrNum2_IS_KM010B_DCZ.mp4
# list index out of range PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum13_PV_KL007B.mp4
# list index out of range PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum4_IS_KL007G.mp4
# list index out of range PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum16_PV_KL007R.mp4
# list index out of range PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum3_PV_KL007B.mp4
# list index out of range PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum14_IS_KL007G.mp4
# list index out of range PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum1_PV_KL007R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL007_TimeOut/Tracking/h5_uncorrected/041824_Cam3_TrNum9_Comp_KL007Y-KL007G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum9_Comp_KL007Y-KL007G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL007_TimeOut/Tracking/h5_uncorrected/041824_Cam3_TrNum6_Ineq_KL007R-KL007G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum6_Ineq_KL007R-KL007G.mp4
# list index out of range PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum2_IS_KL007Y.mp4
# list index out of range PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum15_IS_KL007Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL007_TimeOut/Tracking/h5_uncorrected/041824_Cam3_TrNum8_Ineq_KL007R-KL007Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum8_Ineq_KL007R-KL007Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL007_TimeOut/Tracking/h5_uncorrected/041824_Cam3_TrNum7_Comp_KL007Y-KL007G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum7_Comp_KL007Y-KL007G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL007_TimeOut/Tracking/h5_uncorrected/041824_Cam3_TrNum10_Ineq_KL007Y-KL007B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL007_TimeOut 041824_Cam3_TrNum10_Ineq_KL007Y-KL007B.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum5_IS_EB005Y.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum14_IS_EB005Y.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum15_IS_EB009B.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum6_IS_EB007R.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum3_PV_EB006G.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum1_IS_EB009B.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum2_PV_EB010G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/051424_EB005Y-007R-009B_TimeOut_VEH/Tracking/h5_uncorrected/051424_Cam4_TrNum10_Ineq_EB005Y-EB006G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum10_Ineq_EB005Y-EB006G.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum13_IS_EB007R.mp4
# list index out of range PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum4_PV_EB008G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/051424_EB005Y-007R-009B_TimeOut_VEH/Tracking/h5_uncorrected/051424_Cam4_TrNum8_Ineq_EB005Y-EB008G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum8_Ineq_EB005Y-EB008G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/051424_EB005Y-007R-009B_TimeOut_VEH/Tracking/h5_uncorrected/051424_Cam4_TrNum12_Ineq_EB005Y-EB010G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum12_Ineq_EB005Y-EB010G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/051424_EB005Y-007R-009B_TimeOut_VEH/Tracking/h5_uncorrected/051424_Cam4_TrNum7_Comp_EB005Y-EB007R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 051424_EB005Y-007R-009B_TimeOut_VEH 051424_Cam4_TrNum7_Comp_EB005Y-EB007R.mp4
# list index out of range PairedTestingSessions 022525_PairedTesting_TimeOut_DREADD_KL013-KM016B_SAL-SAL 022525_Cam1_TrNum5_Yoked_KM013R_SAL.mp4
# list index out of range PairedTestingSessions 022525_PairedTesting_TimeOut_DREADD_KL013-KM016B_SAL-SAL 022525_Cam1_TrNum8_Yoked_KM013G_SAL.mp4
# list index out of range PairedTestingSessions 022525_PairedTesting_TimeOut_DREADD_KL013-KM016B_SAL-SAL 022525_Cam1_TrNum3_IS_KM013G_SAL.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/022525_PairedTesting_TimeOut_DREADD_KL013-KM016B_SAL-SAL/Tracking/h5_uncorrected/022525_Cam1_TrNum7_Comp_KM013R-KM013G_SAL-SAL.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 022525_PairedTesting_TimeOut_DREADD_KL013-KM016B_SAL-SAL 022525_Cam1_TrNum7_Comp_KM013R-KM013G_SAL-SAL.mp4
# list index out of range PairedTestingSessions 022525_PairedTesting_TimeOut_DREADD_KL013-KM016B_SAL-SAL 022525_Cam1_TrNum1_IS_KM016B_SAL.mp4
# list index out of range PairedTestingSessions 022525_PairedTesting_TimeOut_DREADD_KL013-KM016B_SAL-SAL 022525_Cam1_TrNum2_IS_KM013R_SAL.mp4
# list index out of range PairedTestingSessions 041625_PairedTesting_TimeOut_DREADD_KM010B-SAL_KM010Y-CNO_KM013G-SAL 041625_Cam2_TrNum2_IS_KM010Y_CNO.mp4
# list index out of range PairedTestingSessions 041625_PairedTesting_TimeOut_DREADD_KM010B-SAL_KM010Y-CNO_KM013G-SAL 041625_Cam2_TrNum3_IS_KM010B_SAL.mp4
# list index out of range PairedTestingSessions 041625_PairedTesting_TimeOut_DREADD_KM010B-SAL_KM010Y-CNO_KM013G-SAL 041625_Cam2_TrNum1_IS_KM013G_SAL.mp4
# list index out of range PairedTestingSessions 041625_PairedTesting_TimeOut_DREADD_KM010B-SAL_KM010Y-CNO_KM013G-SAL 041625_Cam2_TrNum4_Yoked_KM010Y_CNO.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum4_PV_EB012G.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum15_IS_EB015R.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum3_IS_EB017B.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum2_IS_EB015R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/053124_EB011Y-015R-017B_TimeOut_CNO/Tracking/h5_uncorrected/053124_Cam4_TrNum9_Ineq_EB011Y-EB012G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum9_Ineq_EB011Y-EB012G.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum1_IS_EB011Y.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum6_PV_EB018G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/053124_EB011Y-015R-017B_TimeOut_CNO/Tracking/h5_uncorrected/053124_Cam4_TrNum12_Comp_EB011Y-EB015R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum12_Comp_EB011Y-EB015R.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum13_IS_EB017B.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum14_IS_EB011Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/053124_EB011Y-015R-017B_TimeOut_CNO/Tracking/h5_uncorrected/053124_Cam4_TrNum11_Ineq_EB011Y-EB018G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum11_Ineq_EB011Y-EB018G.mp4
# list index out of range PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum5_PV_EB016G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/053124_EB011Y-015R-017B_TimeOut_CNO/Tracking/h5_uncorrected/053124_Cam4_TrNum7_Ineq_EB011Y-EB016G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 053124_EB011Y-015R-017B_TimeOut_CNO 053124_Cam4_TrNum7_Ineq_EB011Y-EB016G.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum14_IS_EB033Y.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum13_IS_EB001R.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum1_IS_EB031B.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum4_PV_EB032G.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum5_IS_EB001R.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum3_IS_EB033Y.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum2_PV_EB034G.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum6_PV_EB002G.mp4
# list index out of range PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum15_IS_EB031B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/051424_EB031B-001R-033Y_TimeOut_VEH/Tracking/h5_uncorrected/051424_Cam3_TrNum9_Comp_EB031B-EB001R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 051424_EB031B-001R-033Y_TimeOut_VEH 051424_Cam3_TrNum9_Comp_EB031B-EB001R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/042224_KL006_TimeOut/Tracking/h5_uncorrected/042224_Cam4_TrNum8_Comp_KL006G-KL006R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum8_Comp_KL006G-KL006R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/042224_KL006_TimeOut/Tracking/h5_uncorrected/042224_Cam4_TrNum6_Ineq_KL006R-KL006B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum6_Ineq_KL006R-KL006B.mp4
# list index out of range PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum3_IS_KL006R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/042224_KL006_TimeOut/Tracking/h5_uncorrected/042224_Cam4_TrNum10_Comp_KL006G-KL006R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum10_Comp_KL006G-KL006R.mp4
# list index out of range PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum14_PV_KL006B.mp4
# list index out of range PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum15_PV_KL006Y.mp4
# list index out of range PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum13_IS_KL006G.mp4
# list index out of range PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum2_PV_KL006B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/042224_KL006_TimeOut/Tracking/h5_uncorrected/042224_Cam4_TrNum9_Ineq_KL006Y-KL006R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum9_Ineq_KL006Y-KL006R.mp4
# list index out of range PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum4_PV_KL006Y.mp4
# list index out of range PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum1_IS_KL006G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/042224_KL006_TimeOut/Tracking/h5_uncorrected/042224_Cam4_TrNum11_Ineq_KL006Y-KL006G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum11_Ineq_KL006Y-KL006G.mp4
# list index out of range PairedTestingSessions 042224_KL006_TimeOut 042224_Cam4_TrNum16_IS_KL006R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/090924_FiberPho_KL007G-KL002_TimeOut/Tracking/h5_uncorrected/090924_Cam1_TrNum9_Ineq_KL007G-KL002R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum9_Ineq_KL007G-KL002R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/090924_FiberPho_KL007G-KL002_TimeOut/Tracking/h5_uncorrected/090924_Cam1_TrNum12_Comp_KL007G-KL007Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum12_Comp_KL007G-KL007Y.mp4
# list index out of range PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum5_IS_KL002B.mp4
# list index out of range PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum3_PV_KL002R.mp4
# list index out of range PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum7_IS_KL007G.mp4
# list index out of range PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum2_PV_KL007B.mp4
# list index out of range PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum1_IS_KL002Y.mp4
# list index out of range PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum6_PV_KL007R.mp4
# list index out of range PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum15_IS_KL007G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/090924_FiberPho_KL007G-KL002_TimeOut/Tracking/h5_uncorrected/090924_Cam1_TrNum11_Ineq_KL007G-KL007R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum11_Ineq_KL007G-KL007R.mp4
# list index out of range PairedTestingSessions 090924_FiberPho_KL007G-KL002_TimeOut 090924_Cam1_TrNum4_IS_KL007Y.mp4
# list index out of range PairedTestingSessions 052024_EB027Y-029R-EB023B_TimeOut_VEH_BAD 052024_Cam2_TrNum4_PV_EB030G.mp4
# list index out of range PairedTestingSessions 052024_EB027Y-029R-EB023B_TimeOut_VEH_BAD 052024_Cam2_TrNum3_PV_EB024G.mp4
# list index out of range PairedTestingSessions 052024_EB027Y-029R-EB023B_TimeOut_VEH_BAD 052024_Cam2_TrNum2_PV_EB028G.mp4
# list index out of range PairedTestingSessions 052024_EB027Y-029R-EB023B_TimeOut_VEH_BAD 052024_Cam2_TrNum6_IS_EB029R.mp4
# list index out of range PairedTestingSessions 052024_EB027Y-029R-EB023B_TimeOut_VEH_BAD 052024_Cam2_TrNum5_IS_EB023B.mp4
# list index out of range PairedTestingSessions 052024_EB027Y-029R-EB023B_TimeOut_VEH_BAD 052024_Cam2_TrNum1_IS_EB027Y.mp4
# list index out of range PairedTestingSessions 102124_FiberPho_HF008Y_HF001R_TimeOut 102124_Cam2_TrNum1_IS_HF006G.mp4
# list index out of range PairedTestingSessions 102124_FiberPho_HF008Y_HF001R_TimeOut 102124_Cam2_TrNum3_IS_HF008Y.mp4
# list index out of range PairedTestingSessions 102124_FiberPho_HF008Y_HF001R_TimeOut 102124_Cam2_TrNum8_IS_HF008Y.mp4
# list index out of range PairedTestingSessions 102124_FiberPho_HF008Y_HF001R_TimeOut 102124_Cam2_TrNum2_IS_HF001R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/102124_FiberPho_HF008Y_HF001R_TimeOut/Tracking/h5_uncorrected/102124_Cam2_TrNum5_Comp_HF008Y-HF006G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 102124_FiberPho_HF008Y_HF001R_TimeOut 102124_Cam2_TrNum5_Comp_HF008Y-HF006G.mp4
# list index out of range PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum3_IS_KL005B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091324_FiberPho_KL005Y_KL007_TimeOut/Tracking/h5_uncorrected/091324_Cam2_TrNum14_Comp_KL005Y-KL005B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum14_Comp_KL005Y-KL005B.mp4
# list index out of range PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum4_IS_KL007G.mp4
# list index out of range PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum15_IS_KL005Y.mp4
# list index out of range PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum5_PV_KL007B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091324_FiberPho_KL005Y_KL007_TimeOut/Tracking/h5_uncorrected/091324_Cam2_TrNum9_Ineq_KL005Y-KL005R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum9_Ineq_KL005Y-KL005R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091324_FiberPho_KL005Y_KL007_TimeOut/Tracking/h5_uncorrected/091324_Cam2_TrNum11_Ineq_KL005Y-KL007B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum11_Ineq_KL005Y-KL007B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091324_FiberPho_KL005Y_KL007_TimeOut/Tracking/h5_uncorrected/091324_Cam2_TrNum13_Ineq_KL005Y-KL005G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum13_Ineq_KL005Y-KL005G.mp4
# list index out of range PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum7_IS_KL005Y.mp4
# list index out of range PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum2_PV_KL005G.mp4
# list index out of range PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum6_IS_KL006R.mp4
# list index out of range PairedTestingSessions 091324_FiberPho_KL005Y_KL007_TimeOut 091324_Cam2_TrNum1_PV_KL005R.mp4
# list index out of range PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum4_PV_KL001G.mp4
# list index out of range PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum2_PV_KL001R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/043024_KL001_TimeOut_Opaque/Tracking/h5_uncorrected/043024_Cam2_TrNum9_Ineq_KL001B-KL001R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum9_Ineq_KL001B-KL001R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/043024_KL001_TimeOut_Opaque/Tracking/h5_uncorrected/043024_Cam2_TrNum11_Ineq_KL001G-KL001Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum11_Ineq_KL001G-KL001Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/043024_KL001_TimeOut_Opaque/Tracking/h5_uncorrected/043024_Cam2_TrNum7_Ineq_KL001Y-KL001R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum7_Ineq_KL001Y-KL001R.mp4
# list index out of range PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum15_PV_KL001R.mp4
# list index out of range PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum1_IS_KL001Y.mp4
# list index out of range PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum14_PV_KL001G.mp4
# list index out of range PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum3_IS_KL001B.mp4
# list index out of range PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum16_IS_KL001Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/043024_KL001_TimeOut_Opaque/Tracking/h5_uncorrected/043024_Cam2_TrNum12_Comp_KL001B-KL001Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum12_Comp_KL001B-KL001Y.mp4
# list index out of range PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum13_IS_KL001B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/043024_KL001_TimeOut_Opaque/Tracking/h5_uncorrected/043024_Cam2_TrNum10_Comp_KL001B-KL001Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 043024_KL001_TimeOut_Opaque 043024_Cam2_TrNum10_Comp_KL001B-KL001Y.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum6_IS_KL001Y.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum1_IS_KL005B.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum16_IS_KL004G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/093024_FiberPho_KL004G-KL001_TimeOut/Tracking/h5_uncorrected/093024_Cam2_TrNum11_Ineq_KL004G-KL001R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum11_Ineq_KL004G-KL001R.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum3_PV_KL004B.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum4_PV_KL008Y.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum2_PV_KL001R.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum8_IS_KL004G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/093024_FiberPho_KL004G-KL001_TimeOut/Tracking/h5_uncorrected/093024_Cam2_TrNum12_Ineq_KL004G-KL008Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum12_Ineq_KL004G-KL008Y.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum5_PV_KL004Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/093024_FiberPho_KL004G-KL001_TimeOut/Tracking/h5_uncorrected/093024_Cam2_TrNum14_Ineq_KL004G-KL004Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum14_Ineq_KL004G-KL004Y.mp4
# list index out of range PairedTestingSessions 093024_FiberPho_KL004G-KL001_TimeOut 093024_Cam2_TrNum7_IS_KL008B.mp4
# list index out of range PairedTestingSessions 041625_PairedTesting_TimeOut_DREADD_KM011B-SAL_KM011Y-CNO-KM013R-SAL 041625_Cam3_TrNum5_Yoked_KM011Y_CNO.mp4
# list index out of range PairedTestingSessions 041625_PairedTesting_TimeOut_DREADD_KM011B-SAL_KM011Y-CNO-KM013R-SAL 041625_Cam3_TrNum1_IS_KM011Y_CNO.mp4
# list index out of range PairedTestingSessions 041625_PairedTesting_TimeOut_DREADD_KM011B-SAL_KM011Y-CNO-KM013R-SAL 041625_Cam3_TrNum2_IS_KM013R_SAL.mp4
# list index out of range PairedTestingSessions 041625_PairedTesting_TimeOut_DREADD_KM011B-SAL_KM011Y-CNO-KM013R-SAL 041625_Cam3_TrNum3_IS_KM011B_SAL.mp4
# list index out of range PairedTestingSessions 030525_PairedTesting_TimeOut_DREADD_KL009-KL011Y_SAL-DCZ 030525_Cam2_TrNum2_IS_KM009R_SAL.mp4
# list index out of range PairedTestingSessions 030525_PairedTesting_TimeOut_DREADD_KL009-KL011Y_SAL-DCZ 030525_Cam2_TrNum1_IS_KM011Y_SAL.mp4
# list index out of range PairedTestingSessions 030525_PairedTesting_TimeOut_DREADD_KL009-KL011Y_SAL-DCZ 030525_Cam2_TrNum5_Yoked_KM009R_SAL.mp4
# list index out of range PairedTestingSessions 030525_PairedTesting_TimeOut_DREADD_KL009-KL011Y_SAL-DCZ 030525_Cam2_TrNum7_Yoked_KM009G_DCZ.mp4
# list index out of range PairedTestingSessions 030525_PairedTesting_TimeOut_DREADD_KL009-KL011Y_SAL-DCZ 030525_Cam2_TrNum3_IS_KM009G_DCZ.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/030525_PairedTesting_TimeOut_DREADD_KL009-KL011Y_SAL-DCZ/Tracking/h5_uncorrected/030525_Cam2_TrNum6_Comp_KM009R-KM009G_SAL-DCZ.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 030525_PairedTesting_TimeOut_DREADD_KL009-KL011Y_SAL-DCZ 030525_Cam2_TrNum6_Comp_KM009R-KM009G_SAL-DCZ.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum6_IS_EB015R.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum3_IS_EB023B.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum13_IS_EB011Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/052324_EB015R-011Y_023B_TimeOut_VEH/Tracking/h5_uncorrected/052324_Cam2_TrNum8_Ineq_EB015R-EB016G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum8_Ineq_EB015R-EB016G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/052324_EB015R-011Y_023B_TimeOut_VEH/Tracking/h5_uncorrected/052324_Cam2_TrNum11_Ineq_EB015R-EB024G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum11_Ineq_EB015R-EB024G.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum14_IS_EB015R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/052324_EB015R-011Y_023B_TimeOut_VEH/Tracking/h5_uncorrected/052324_Cam2_TrNum9_Ineq_EB015R-EB012G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum9_Ineq_EB015R-EB012G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/052324_EB015R-011Y_023B_TimeOut_VEH/Tracking/h5_uncorrected/052324_Cam2_TrNum10_Comp_EB015R-EB011Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum10_Comp_EB015R-EB011Y.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum4_IS_EB011Y.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum15_IS_EB023B.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum2_PV_EB012G.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum1_PV_EB016G.mp4
# list index out of range PairedTestingSessions 052324_EB015R-011Y_023B_TimeOut_VEH 052324_Cam2_TrNum5_PV_EB024G.mp4
# list index out of range PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum5_IS_KL006R.mp4
# list index out of range PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum4_IS_KL008G.mp4
# list index out of range PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum2_PV_KL001R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/092624_FiberPho_KL002B-KL006_2X_TimeOut/Tracking/h5_uncorrected/092624_Cam2_TrNum8_Comp_KL002B-KL002Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum8_Comp_KL002B-KL002Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/092624_FiberPho_KL002B-KL006_2X_TimeOut/Tracking/h5_uncorrected/092624_Cam2_TrNum13_Ineq_KL002B-KL002R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum13_Ineq_KL002B-KL002R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/092624_FiberPho_KL002B-KL006_2X_TimeOut/Tracking/h5_uncorrected/092624_Cam2_TrNum9_Ineq_KL002B-KL001R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum9_Ineq_KL002B-KL001R.mp4
# list index out of range PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum15_IS_KL002B.mp4
# list index out of range PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum1_PV_KL002G.mp4
# list index out of range PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum6_IS_KL002Y.mp4
# list index out of range PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum3_PV_KL002R.mp4
# list index out of range PairedTestingSessions 092624_FiberPho_KL002B-KL006_2X_TimeOut 092624_Cam2_TrNum7_IS_KL002B.mp4
# list index out of range PairedTestingSessions 022825_PairedTesting_TimeOut_DREADD_KL015-KL010Y_DCZ-DCZ 022825_Cam2_TrNum7_Yoked_KM015G_DCZ.mp4
# list index out of range PairedTestingSessions 022825_PairedTesting_TimeOut_DREADD_KL015-KL010Y_DCZ-DCZ 022825_Cam2_TrNum9_Yoked_KM015R_DCZ.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/022825_PairedTesting_TimeOut_DREADD_KL015-KL010Y_DCZ-DCZ/Tracking/h5_uncorrected/022825_Cam2_TrNum5_Comp_KM015R-KM015G_DCZ-DCZ.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 022825_PairedTesting_TimeOut_DREADD_KL015-KL010Y_DCZ-DCZ 022825_Cam2_TrNum5_Comp_KM015R-KM015G_DCZ-DCZ.mp4
# list index out of range PairedTestingSessions 022825_PairedTesting_TimeOut_DREADD_KL015-KL010Y_DCZ-DCZ 022825_Cam2_TrNum3_IS_KM015G_DCZ.mp4
# list index out of range PairedTestingSessions 022825_PairedTesting_TimeOut_DREADD_KL015-KL010Y_DCZ-DCZ 022825_Cam2_TrNum2_IS_KM015R_DCZ.mp4
# list index out of range PairedTestingSessions 022825_PairedTesting_TimeOut_DREADD_KL015-KL010Y_DCZ-DCZ 022825_Cam2_TrNum1_IS_KM010Y_SAL.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL008_TimeOut/Tracking/h5_uncorrected/041824_Cam2_TrNum8_Ineq_KL008B-KL008Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum8_Ineq_KL008B-KL008Y.mp4
# list index out of range PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum13_IS_KL008G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL008_TimeOut/Tracking/h5_uncorrected/041824_Cam2_TrNum10_Ineq_KL008R-KL008G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum10_Ineq_KL008R-KL008G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL008_TimeOut/Tracking/h5_uncorrected/041824_Cam2_TrNum6_Ineq_KL008R-KL008B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum6_Ineq_KL008R-KL008B.mp4
# list index out of range PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum14_PV_KL008R.mp4
# list index out of range PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum4_PV_KL008Y.mp4
# list index out of range PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum1_IS_KL008B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL008_TimeOut/Tracking/h5_uncorrected/041824_Cam2_TrNum11_Ineq_KL008G-KL008Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum11_Ineq_KL008G-KL008Y.mp4
# list index out of range PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum3_PV_KL008R.mp4
# list index out of range PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum15_IS_KL008B.mp4
# list index out of range PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum2_IS_KL008G.mp4
# list index out of range PairedTestingSessions 041824_KL008_TimeOut 041824_Cam2_TrNum16_PV_KL008Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL003_TimeOut/Tracking/h5_uncorrected/041924_Cam3_TrNum9_Ineq_KL003R-KL003B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum9_Ineq_KL003R-KL003B.mp4
# list index out of range PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum13_IS_KL003G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL003_TimeOut/Tracking/h5_uncorrected/041924_Cam3_TrNum5_Ineq_KL003G-KL003Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum5_Ineq_KL003G-KL003Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL003_TimeOut/Tracking/h5_uncorrected/041924_Cam3_TrNum11_Ineq_KL003R-KL003G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum11_Ineq_KL003R-KL003G.mp4
# list index out of range PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum1_IS_KL003G.mp4
# list index out of range PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum16_PV_KL003Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL003_TimeOut/Tracking/h5_uncorrected/041924_Cam3_TrNum7_Ineq_KL003B-KL003Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum7_Ineq_KL003B-KL003Y.mp4
# list index out of range PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum15_PV_KL003R.mp4
# list index out of range PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum3_PV_KL003R.mp4
# list index out of range PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum14_IS_KL003B.mp4
# list index out of range PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum2_IS_KL003B.mp4
# list index out of range PairedTestingSessions 041924_KL003_TimeOut 041924_Cam3_TrNum4_PV_KL003Y.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum14_IS_EB023B.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum15_IS_EB019Y.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum1_PV_EB022G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/051024_EB023B-021R-019Y_TimeOut_CNO/Tracking/h5_uncorrected/051024_Cam1_TrNum9_Comp_EB023B-EB021R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum9_Comp_EB023B-EB021R.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum3_IS_EB021R.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum13_IS_EB021R.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum4_PV_EB020G.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum6_IS_EB019Y.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum5_IS_EB023B.mp4
# list index out of range PairedTestingSessions 051024_EB023B-021R-019Y_TimeOut_CNO 051024_Cam1_TrNum2_PV_EB024G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/050124_KL006_TimeOut_Translucent/Tracking/h5_uncorrected/050124_Cam3_TrNum6_Ineq_KL006R-KL006B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum6_Ineq_KL006R-KL006B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/050124_KL006_TimeOut_Translucent/Tracking/h5_uncorrected/050124_Cam3_TrNum9_Ineq_KL006Y-KL006R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum9_Ineq_KL006Y-KL006R.mp4
# list index out of range PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum14_IS_KL006R.mp4
# list index out of range PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum15_PV_KL006B.mp4
# list index out of range PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum4_PV_KL006Y.mp4
# list index out of range PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum13_IS_KL006G.mp4
# list index out of range PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum2_IS_KL006G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/050124_KL006_TimeOut_Translucent/Tracking/h5_uncorrected/050124_Cam3_TrNum8_Ineq_KL006Y-KL006G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum8_Ineq_KL006Y-KL006G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/050124_KL006_TimeOut_Translucent/Tracking/h5_uncorrected/050124_Cam3_TrNum12_Comp_KL006G-KL006R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum12_Comp_KL006G-KL006R.mp4
# list index out of range PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum3_PV_KL006B.mp4
# list index out of range PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum1_IS_KL006R.mp4
# list index out of range PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum16_PV_KL006Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/050124_KL006_TimeOut_Translucent/Tracking/h5_uncorrected/050124_Cam3_TrNum10_Comp_KL006G-KL006R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 050124_KL006_TimeOut_Translucent 050124_Cam3_TrNum10_Comp_KL006G-KL006R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/022025_PairedTesting_TimeOut_DREADD_KL011-KM015G_DCZ-SAL/Tracking/h5_uncorrected/022025_Cam2_TrNum6_Comp_KM011B-KM011Y_DCZ-DCZ.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 022025_PairedTesting_TimeOut_DREADD_KL011-KM015G_DCZ-SAL 022025_Cam2_TrNum6_Comp_KM011B-KM011Y_DCZ-DCZ.mp4
# list index out of range PairedTestingSessions 022025_PairedTesting_TimeOut_DREADD_KL011-KM015G_DCZ-SAL 022025_Cam2_TrNum5_Yoked_KM011B_DCZ.mp4
# list index out of range PairedTestingSessions 022025_PairedTesting_TimeOut_DREADD_KL011-KM015G_DCZ-SAL 022025_Cam2_TrNum4_Yoked_KM011Y_SAL.mp4
# list index out of range PairedTestingSessions 022025_PairedTesting_TimeOut_DREADD_KL011-KM015G_DCZ-SAL 022025_Cam2_TrNum2_IS_KM011B_DCZ.mp4
# list index out of range PairedTestingSessions 022025_PairedTesting_TimeOut_DREADD_KL011-KM015G_DCZ-SAL 022025_Cam2_TrNum3_IS_KM015G_SAL.mp4
# list index out of range PairedTestingSessions 022025_PairedTesting_TimeOut_DREADD_KL011-KM015G_DCZ-SAL 022025_Cam2_TrNum1_IS_KM011Y_SAL.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/092424_FiberPho_KL005Y-KL008_TimeOut/Tracking/h5_uncorrected/092424_Cam2_TrNum11_Ineq_KL005Y-KL005G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum11_Ineq_KL005Y-KL005G.mp4
# list index out of range PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum6_PV_KL001G.mp4
# list index out of range PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum5_IS_KL003G.mp4
# list index out of range PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum3_IS_KL005B.mp4
# list index out of range PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum2_IS_KL008B.mp4
# list index out of range PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum4_PV_KL005G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/092424_FiberPho_KL005Y-KL008_TimeOut/Tracking/h5_uncorrected/092424_Cam2_TrNum9_Ineq_KL005Y-KL001G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum9_Ineq_KL005Y-KL001G.mp4
# list index out of range PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum7_IS_KL005Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/092424_FiberPho_KL005Y-KL008_TimeOut/Tracking/h5_uncorrected/092424_Cam2_TrNum10_Comp_KL005Y-KL005B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum10_Comp_KL005Y-KL005B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/092424_FiberPho_KL005Y-KL008_TimeOut/Tracking/h5_uncorrected/092424_Cam2_TrNum13_Ineq_KL005Y-KL005R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum13_Ineq_KL005Y-KL005R.mp4
# list index out of range PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum1_PV_KL005R.mp4
# list index out of range PairedTestingSessions 092424_FiberPho_KL005Y-KL008_TimeOut 092424_Cam2_TrNum15_IS_KL005Y.mp4
# list index out of range PairedTestingSessions 020424_KL002_NoTimeOut 020424_Cam1_TrNum4_IS_KL002B-.mp4
# ...
# list index out of range PairedTestingSessions 100324_FiberPho_KL005Y_TimeOut_Opaque 100324_Cam1_TrNum9_IS_KL005Y.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL005Y_TimeOut_Opaque 100324_Cam1_TrNum3_IS_KL005B.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL005Y_TimeOut_Opaque 100324_Cam1_TrNum1_PV_KL005R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/100324_FiberPho_KL005Y_TimeOut_Opaque/Tracking/h5_uncorrected/100324_Cam1_TrNum7_Ineq_KL005Y-KL005G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 100324_FiberPho_KL005Y_TimeOut_Opaque 100324_Cam1_TrNum7_Ineq_KL005Y-KL005G.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL005Y_TimeOut_Opaque 100324_Cam1_TrNum2_PV_KL005G.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL005Y_TimeOut_Opaque 100324_Cam1_TrNum4_IS_KL005Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/100324_FiberPho_KL005Y_TimeOut_Opaque/Tracking/h5_uncorrected/100324_Cam1_TrNum5_Ineq_KL005Y-KL005R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 100324_FiberPho_KL005Y_TimeOut_Opaque 100324_Cam1_TrNum5_Ineq_KL005Y-KL005R.mp4
# list index out of range PairedTestingSessions 022725_PairedTesting_TimeOut_DREADD_KL013-KL009_DCZ-SAL 022725_Cam1_TrNum6_Yoked_KL013R_DCZ.mp4
# list index out of range PairedTestingSessions 022725_PairedTesting_TimeOut_DREADD_KL013-KL009_DCZ-SAL 022725_Cam1_TrNum3_IS_KL009G_SAL.mp4
# list index out of range PairedTestingSessions 022725_PairedTesting_TimeOut_DREADD_KL013-KL009_DCZ-SAL 022725_Cam1_TrNum2_IS_KL009R_SAL.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/022725_PairedTesting_TimeOut_DREADD_KL013-KL009_DCZ-SAL/Tracking/h5_uncorrected/022725_Cam1_TrNum8_Comp_KL013R-KL013G_DCZ-SAL.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 022725_PairedTesting_TimeOut_DREADD_KL013-KL009_DCZ-SAL 022725_Cam1_TrNum8_Comp_KL013R-KL013G_DCZ-SAL.mp4
# list index out of range PairedTestingSessions 022725_PairedTesting_TimeOut_DREADD_KL013-KL009_DCZ-SAL 022725_Cam1_TrNum4_IS_KL013G_SAL.mp4
# list index out of range PairedTestingSessions 022725_PairedTesting_TimeOut_DREADD_KL013-KL009_DCZ-SAL 022725_Cam1_TrNum1_IS_KL013R_DCZ.mp4
# list index out of range PairedTestingSessions 022725_PairedTesting_TimeOut_DREADD_KL013-KL009_DCZ-SAL 022725_Cam1_TrNum7_Yoked_KL013G_SAL.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum6_IS_EB005Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/052424_EB005Y-007R-023B_TimeOut_CNO/Tracking/h5_uncorrected/052424_Cam1_TrNum12_Ineq_EB005Y-EB024G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum12_Ineq_EB005Y-EB024G.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum13_IS_EB023B.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum14_IS_EB005Y.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum1_IS_EB007R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/052424_EB005Y-007R-023B_TimeOut_CNO/Tracking/h5_uncorrected/052424_Cam1_TrNum10_Ineq_EB005Y-EB008G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum10_Ineq_EB005Y-EB008G.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum4_PV_EB006G.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum3_IS_EB023B.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum5_PV_EB024G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/052424_EB005Y-007R-023B_TimeOut_CNO/Tracking/h5_uncorrected/052424_Cam1_TrNum8_Ineq_EB005Y-EB006G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum8_Ineq_EB005Y-EB006G.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum2_PV_EB008G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/052424_EB005Y-007R-023B_TimeOut_CNO/Tracking/h5_uncorrected/052424_Cam1_TrNum7_Comp_EB005Y-EB007R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum7_Comp_EB005Y-EB007R.mp4
# list index out of range PairedTestingSessions 052424_EB005Y-007R-023B_TimeOut_CNO 052424_Cam1_TrNum15_IS_EB007R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091124_FiberPho_KL002Y-KL005_TimeOut/Tracking/h5_uncorrected/091124_Cam1_TrNum11_Ineq_KL002Y-KL002R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum11_Ineq_KL002Y-KL002R.mp4
# list index out of range PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum2_PV_KL002G.mp4
# list index out of range PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum7_IS_KL002Y.mp4
# list index out of range PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum1_IS_KL004R.mp4
# list index out of range PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum5_IS_KL002B.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091124_FiberPho_KL002Y-KL005_TimeOut/Tracking/h5_uncorrected/091124_Cam1_TrNum12_Comp_KL002Y-KL002B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum12_Comp_KL002Y-KL002B.mp4
# list index out of range PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum4_IS_KL005B.mp4
# list index out of range PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum3_PV_KL005R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091124_FiberPho_KL002Y-KL005_TimeOut/Tracking/h5_uncorrected/091124_Cam1_TrNum13_Ineq_KL002Y-KL002G.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum13_Ineq_KL002Y-KL002G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091124_FiberPho_KL002Y-KL005_TimeOut/Tracking/h5_uncorrected/091124_Cam1_TrNum9_Ineq_KL002Y-KL005R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum9_Ineq_KL002Y-KL005R.mp4
# list index out of range PairedTestingSessions 091124_FiberPho_KL002Y-KL005_TimeOut 091124_Cam1_TrNum6_PV_KL002R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/100324_FiberPho_KL006G_TimeOut_Opaque/Tracking/h5_uncorrected/100324_Cam2_TrNum8_Comp_KL006G-KL006R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 100324_FiberPho_KL006G_TimeOut_Opaque 100324_Cam2_TrNum8_Comp_KL006G-KL006R.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL006G_TimeOut_Opaque 100324_Cam2_TrNum4_IS_KL006G.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL006G_TimeOut_Opaque 100324_Cam2_TrNum2_PV_KL006Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/100324_FiberPho_KL006G_TimeOut_Opaque/Tracking/h5_uncorrected/100324_Cam2_TrNum5_Ineq_KL006G-KL006Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 100324_FiberPho_KL006G_TimeOut_Opaque 100324_Cam2_TrNum5_Ineq_KL006G-KL006Y.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL006G_TimeOut_Opaque 100324_Cam2_TrNum3_IS_KL006R.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL006G_TimeOut_Opaque 100324_Cam2_TrNum1_PV_KL006B.mp4
# list index out of range PairedTestingSessions 100324_FiberPho_KL006G_TimeOut_Opaque 100324_Cam2_TrNum9_IS_KL006G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL001_TimeOut/Tracking/h5_uncorrected/041924_Cam2_TrNum11_Ineq_KL001B-KL001R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum11_Ineq_KL001B-KL001R.mp4
# list index out of range PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum1_PV_KL001G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL001_TimeOut/Tracking/h5_uncorrected/041924_Cam2_TrNum8_Ineq_KL001Y-KL001R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum8_Ineq_KL001Y-KL001R.mp4
# list index out of range PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum14_PV_KL001G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL001_TimeOut/Tracking/h5_uncorrected/041924_Cam2_TrNum7_Comp_KL001B-KL001Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum7_Comp_KL001B-KL001Y.mp4
# list index out of range PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum15_PV_KL001R.mp4
# list index out of range PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum2_IS_KL001Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL001_TimeOut/Tracking/h5_uncorrected/041924_Cam2_TrNum10_Ineq_KL001G-KL001Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum10_Ineq_KL001G-KL001Y.mp4
# list index out of range PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum16_IS_KL001Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041924_KL001_TimeOut/Tracking/h5_uncorrected/041924_Cam2_TrNum5_Comp_KL001B-KL001Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum5_Comp_KL001B-KL001Y.mp4
# list index out of range PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum4_PV_KL001R.mp4
# list index out of range PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum3_IS_KL001B.mp4
# list index out of range PairedTestingSessions 041924_KL001_TimeOut 041924_Cam2_TrNum13_IS_KL001B.mp4
# list index out of range PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum1_PV_KL006B.mp4
# list index out of range PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum6_PV_KL007B.mp4
# list index out of range PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum5_IS_KL006R.mp4
# list index out of range PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum15_IS_KL006G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091624_FiberPho_KL006G-KL007_TimeOut/Tracking/h5_uncorrected/091624_Cam1_TrNum13_Ineq_KL006G-KL006Y.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum13_Ineq_KL006G-KL006Y.mp4
# list index out of range PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum2_PV_KL006Y.mp4
# list index out of range PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum4_IS_KL007Y.mp4
# list index out of range PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum3_IS_KL005Y.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/091624_FiberPho_KL006G-KL007_TimeOut/Tracking/h5_uncorrected/091624_Cam1_TrNum10_Comp_KL006G-KL006R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum10_Comp_KL006G-KL006R.mp4
# list index out of range PairedTestingSessions 091624_FiberPho_KL006G-KL007_TimeOut 091624_Cam1_TrNum7_IS_KL006G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL005_TimeOut/Tracking/h5_uncorrected/041824_Cam4_TrNum8_Ineq_KL005B-KL005R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL005_TimeOut 041824_Cam4_TrNum8_Ineq_KL005B-KL005R.mp4
# list index out of range PairedTestingSessions 041824_KL005_TimeOut 041824_Cam4_TrNum14_IS_KL005B.mp4
# list index out of range PairedTestingSessions 041824_KL005_TimeOut 041824_Cam4_TrNum13_IS_KL005Y.mp4
# list index out of range PairedTestingSessions 041824_KL005_TimeOut 041824_Cam4_TrNum2_IS_KL005B.mp4
# list index out of range PairedTestingSessions 041824_KL005_TimeOut 041824_Cam4_TrNum15_PV_KL005G.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL005_TimeOut/Tracking/h5_uncorrected/041824_Cam4_TrNum10_Ineq_KL005Y-KL005R.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL005_TimeOut 041824_Cam4_TrNum10_Ineq_KL005Y-KL005R.mp4
# list index out of range PairedTestingSessions 041824_KL005_TimeOut 041824_Cam4_TrNum3_PV_KL005R.mp4
# [Errno 2] Unable to synchronously open file (unable to open file: name = '/gpfs/radev/pi/saxena/aj764/PairedTestingSessions/041824_KL005_TimeOut/Tracking/h5_uncorrected/041824_Cam4_TrNum12_Comp_KL005Y-KL005B.predictions.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0) PairedTestingSessions 041824_KL005_TimeOut 041824_Cam4_TrNum12_Comp_KL005Y-KL005B.mp4

# %%
df
# Out:
#                         dir  \
# 0     PairedTestingSessions
# 1     PairedTestingSessions
# 2     PairedTestingSessions
# 3     PairedTestingSessions
# 4     PairedTestingSessions
# ...                     ...
# 1095   Training_COOPERATION
# 1096   Training_COOPERATION
# 1097   Training_COOPERATION
# 1098   Training_COOPERATION
# 1099   Training_COOPERATION
#
#                                                 session  \
# 0     022125_PairedTesting_TimeOut_DREADD_KM010-KM01...
# 1     022125_PairedTesting_TimeOut_DREADD_KM010-KM01...
# 2     022125_PairedTesting_TimeOut_DREADD_KM010-KM01...
# 3                                  041824_KL007_TimeOut
# 4                                  041824_KL007_TimeOut
# ...                                                 ...
# 1095                                             041224
# 1096                                             041224
# 1097                                             041224
# 1098                                             041224
# 1099                                             041224
#
#                                                   video color type color pair  \
# 0         022125_Cam1_TrNum8_Coop_KM010Y-KM015G_DCZ-SAL     collar         GY
# 1         022125_Cam1_TrNum9_Coop_KM010B-KM010Y_DCZ-DCZ     collar         YB
# 2         022125_Cam1_TrNum7_Coop_KM010B-KM015G_DCZ-SAL     collar         GB
# 3                041824_Cam3_TrNum11_Coop_KL007Y-KL007G       dyed         GY
# 4                 041824_Cam3_TrNum5_Coop_KL007Y-KL007G       dyed         GY
# ...                                                 ...        ...        ...
# 1095  041224_COOPTRAIN_LARGEARENA_EB009B-EB019Y_Camera4       dyed         YB
# 1096  041224_COOPTRAIN_LARGEARENA_EB027Y-EB029R_Camera2       dyed         RY
# 1097  041224_COOPTRAIN_LARGEARENA_EB021R-EB023B_Camera1       dyed         RB
# 1098  041224_COOPTRAIN_LARGEARENA_EB001R-EB003B_Camera1       dyed         RB
# 1099  041224_COOPTRAIN_LARGEARENA_EB031B-EB033Y_Camera3       dyed         YB
#
#       tracked     error  lever    mag  event id  fiber pho  coop thresh  \
# 0       False       NaN  False  False     False      False          NaN
# 1        True  0.415569  False  False     False      False          NaN
# 2       False       NaN  False  False     False      False          NaN
# 3        True  0.293726   True   True      True      False          1.0
# 4        True  0.292777   True   True      True      False          1.0
# ...       ...       ...    ...    ...       ...        ...          ...
# 1095     True  0.362437   True  False      True      False          5.0
# 1096     True  0.222160   True   True      True      False          5.0
# 1097     True  0.255226   True   True      True      False          5.0
# 1098     True  0.112877   True   True      True      False          5.0
# 1099     True  0.172015   True  False      True      False          5.0
#
#           animal id cohort       visual vehicle  familiar
# 0     KM010Y-KM015G     KM  transparent     DCZ    unsure
# 1     KM010B-KM010Y     KM  transparent     DCZ    unsure
# 2     KM010B-KM015G     KM  transparent     DCZ    unsure
# 3     KL007Y-KL007G     KL  transparent     NaN  familiar
# 4     KL007Y-KL007G     KL  transparent     NaN  familiar
# ...             ...    ...          ...     ...       ...
# 1095  EB009B-EB019Y     EB  transparent     NaN  familiar
# 1096  EB027Y-EB029R     EB  transparent     NaN  familiar
# 1097  EB021R-EB023B     EB  transparent     NaN  familiar
# 1098  EB001R-EB003B     EB  transparent     NaN  familiar
# 1099  EB031B-EB033Y     EB  transparent     NaN  familiar
#
# [1100 rows x 17 columns]

# %%
df.to_csv('all_coop_uncorrected.csv', index=False)
# df = pd.read_csv('all_coop.csv')

# %%
good = df[(df['error'] < 0.2) & (df['lever']) & (df['mag']) & (df['familiar'] == 'familiar') & (df['visual'] == 'transparent')& (df['vehicle'] != 'VEH')]
thresh = np.unique(df['coop thresh'])
counts = []
for thre in thresh:
    count = len(good[good['coop thresh'] == thre])
    counts.append(count)
    print(thre, count)
# Out:
# 1.0 147
# 1.25 10
# 1.5 12
# 2.0 19
# 3.0 49
# 4.0 9
# 5.0 16
# 6.0 4
# nan 0

# %%
import matplotlib.pyplot as plt

# %%
plt.bar([str(x) for x in thresh], counts)
# Out:
# <BarContainer object of 9 artists>

# %%
df[(df['error'] < 0.2) & (df['lever']) & (df['mag']) & (df['familiar'] == 'familiar')]
# Out:
#                         dir                              session  \
# 11    PairedTestingSessions  053124_EB011Y-015R-017B_TimeOut_CNO
# 12    PairedTestingSessions  053124_EB011Y-015R-017B_TimeOut_CNO
# 13    PairedTestingSessions  051424_EB031B-001R-033Y_TimeOut_VEH
# 14    PairedTestingSessions  051424_EB031B-001R-033Y_TimeOut_VEH
# 15    PairedTestingSessions                 042224_KL006_TimeOut
# ...                     ...                                  ...
# 1088   Training_COOPERATION                               042424
# 1089   Training_COOPERATION                               040424
# 1090   Training_COOPERATION                               040424
# 1093   Training_COOPERATION                               041224
# 1098   Training_COOPERATION                               041224
#
#                                                   video color type color pair  \
# 11                053124_Cam4_TrNum8_Coop_EB011Y-EB015R       dyed         RY
# 12               053124_Cam4_TrNum10_Coop_EB011Y-EB017B       dyed         YB
# 13                051424_Cam3_TrNum7_Coop_EB031B-EB033Y       dyed         YB
# 14               051424_Cam3_TrNum11_Coop_EB031B-EB001R       dyed         RB
# 15               042224_Cam4_TrNum12_Coop_KL006G-KL006R       dyed         RG
# ...                                                 ...        ...        ...
# 1088  042424_COOPTRAIN_LARGEARENA_EB011Y-EB015R_Camera2       dyed         RY
# 1089  040424_COOPTRAIN_LARGEARENA_KL005B-KL005Y_Camera1       dyed         YB
# 1090  040424_COOPTRAIN_LARGEARENA_KL006R-KL006G_Camera2       dyed         RG
# 1093  041224_COOPTRAIN_LARGEARENA_EB011Y-EB015R_Camera3       dyed         RY
# 1098  041224_COOPTRAIN_LARGEARENA_EB001R-EB003B_Camera1       dyed         RB
#
#       tracked     error  lever   mag  event id  fiber pho  coop thresh  \
# 11       True  0.064760   True  True      True      False          1.0
# 12       True  0.119958   True  True      True      False          1.0
# 13       True  0.064188   True  True      True      False          1.0
# 14       True  0.034926   True  True      True      False          1.0
# 15       True  0.039610   True  True      True      False          1.0
# ...       ...       ...    ...   ...       ...        ...          ...
# 1088     True  0.110486   True  True      True      False          1.0
# 1089     True  0.062045   True  True      True      False          1.0
# 1090     True  0.091414   True  True      True      False          1.0
# 1093     True  0.127609   True  True      True      False          5.0
# 1098     True  0.112877   True  True      True      False          5.0
#
#           animal id cohort       visual vehicle  familiar
# 11    EB011Y-EB015R     EB  transparent     CNO  familiar
# 12    EB011Y-EB017B     EB  transparent     CNO  familiar
# 13    EB031B-EB033Y     EB  transparent     VEH  familiar
# 14    EB031B-EB001R     EB  transparent     VEH  familiar
# 15    KL006G-KL006R     KL  transparent     NaN  familiar
# ...             ...    ...          ...     ...       ...
# 1088  EB011Y-EB015R     EB  transparent     NaN  familiar
# 1089  KL005B-KL005Y     KL  transparent     NaN  familiar
# 1090  KL006R-KL006G     KL  transparent     NaN  familiar
# 1093  EB011Y-EB015R     EB  transparent     NaN  familiar
# 1098  EB001R-EB003B     EB  transparent     NaN  familiar
#
# [287 rows x 17 columns]

# %%
df[~df['tracked'] & (df['color type'] == 'dyed') & (df['color pair'] != 'GB')]
# Out:
#                        dir                               session  \
# 97   PairedTestingSessions                  030624_KL001_TimeOut
# 118  PairedTestingSessions  091024_FiberPho_KL008G-KL005_TimeOut
# 703   Training_COOPERATION                                071124
# 704   Training_COOPERATION                                071124
# 831   Training_COOPERATION                                071024
#
#                                          video color type color pair  tracked  \
# 97       030624_Cam1_TrNum9_Coop_KL001B-KL001Y       dyed         YB    False
# 118     091024_Cam2_TrNum12_Coop_KL008G-KL005Y       dyed         GY    False
# 703  071124_COOPTRAIN_LARGEARENA_HF003B-HF004Y       dyed         YB    False
# 704  071124_COOPTRAIN_LARGEARENA_HF006G-HF008Y       dyed         GY    False
# 831  071024_COOPTRAIN_LARGEARENA_HF006G-HF008Y       dyed         GY    False
#
#      error  lever    mag  event id  fiber pho  coop thresh      animal id  \
# 97     NaN  False  False     False      False          NaN  KL001B-KL001Y
# 118    NaN  False  False     False       True          NaN  KL008G-KL005Y
# 703    NaN   True   True      True      False          1.0  HF003B-HF004Y
# 704    NaN   True   True      True      False          1.0  HF006G-HF008Y
# 831    NaN   True   True      True      False          1.0  HF006G-HF008Y
#
#     cohort       visual vehicle    familiar
# 97      KL  transparent     NaN    familiar
# 118     KL  transparent     NaN  unfamiliar
# 703     HF  transparent     NaN    familiar
# 704     HF  transparent     NaN    familiar
# 831     HF  transparent     NaN    familiar

# %%
df[~df['tracked'] & (df['color type'] == 'collar') & (df['color pair'] == 'RG')]
# Out:
#                        dir session                                      video  \
# 943   Training_COOPERATION  111324  111324_COOPTRAIN_LARGEARENA_NM011R-NM011G
# 1037  Training_COOPERATION  120324  120324_COOPTRAIN_LARGEARENA_NF019R-NF019G
#
#      color type color pair  tracked  error  lever   mag  event id  fiber pho  \
# 943      collar         RG    False    NaN   True  True      True      False
# 1037     collar         RG    False    NaN   True  True      True      False
#
#       coop thresh      animal id cohort       visual vehicle  familiar
# 943           2.0  NM011R-NM011G     NM  transparent     NaN  familiar
# 1037          5.0  NF019R-NF019G     NF  transparent     NaN  familiar

# %%
np.unique

# %%
df.shape
# Out:
# (1100, 11)

# %%
df[(df['dir'] == 'Training_COOPERATION')]
# Out:
#                        dir session  \
# 667   Training_COOPERATION  071524
# 668   Training_COOPERATION  071524
# 669   Training_COOPERATION  071524
# 670   Training_COOPERATION  111924
# 671   Training_COOPERATION  111924
# ...                    ...     ...
# 1095  Training_COOPERATION  041224
# 1096  Training_COOPERATION  041224
# 1097  Training_COOPERATION  041224
# 1098  Training_COOPERATION  041224
# 1099  Training_COOPERATION  041224
#
#                                                   video color type color pair  \
# 667   071524_COOPTRAIN_LARGEARENA_HF003B-HF004Y_Camera3       dyed         YB
# 668   071524_COOPTRAIN_LARGEARENA_HF006G-HF008Y_Camera4       dyed         GY
# 669   071524_COOPTRAIN_LARGEARENA_HF001R-HF002G_Camera2       dyed         RG
# 670   111924_COOPTRAIN_LARGEARENA_NF008B-NF008Y_Camera3     collar         YB
# 671   111924_COOPTRAIN_LARGEARENA_NM002B-NM002Y_Camera2     collar         YB
# ...                                                 ...        ...        ...
# 1095  041224_COOPTRAIN_LARGEARENA_EB009B-EB019Y_Camera4       dyed         YB
# 1096  041224_COOPTRAIN_LARGEARENA_EB027Y-EB029R_Camera2       dyed         RY
# 1097  041224_COOPTRAIN_LARGEARENA_EB021R-EB023B_Camera1       dyed         RB
# 1098  041224_COOPTRAIN_LARGEARENA_EB001R-EB003B_Camera1       dyed         RB
# 1099  041224_COOPTRAIN_LARGEARENA_EB031B-EB033Y_Camera3       dyed         YB
#
#       tracked     error  lever    mag  event id  fiber pho
# 667      True  0.495695   True   True      True      False
# 668      True  0.469171   True   True      True      False
# 669      True  0.457855   True   True      True      False
# 670      True  0.323013   True   True      True      False
# 671      True  0.521202   True   True      True      False
# ...       ...       ...    ...    ...       ...        ...
# 1095     True  0.362437   True  False      True      False
# 1096     True  0.005213   True   True      True      False
# 1097     True  0.004507   True   True      True      False
# 1098     True  0.002757   True   True      True      False
# 1099     True  0.004061   True  False      True      False
#
# [433 rows x 11 columns]

# %%
df[(df['dir'] == 'Training_COOPERATION') & (df['tracked']) & (df['error'] < 0.2) & (df['lever']) & (df['mag'])]
# Out:
#                        dir session  \
# 677   Training_COOPERATION  111924
# 678   Training_COOPERATION  111924
# 680   Training_COOPERATION  112724
# 691   Training_COOPERATION  120624
# 696   Training_COOPERATION  120624
# ...                    ...     ...
# 1093  Training_COOPERATION  041224
# 1094  Training_COOPERATION  041224
# 1096  Training_COOPERATION  041224
# 1097  Training_COOPERATION  041224
# 1098  Training_COOPERATION  041224
#
#                                                   video color type color pair  \
# 677   111924_COOPTRAIN_LARGEARENA_NM003R-NM003G_Camera2     collar         RG
# 678   111924_COOPTRAIN_LARGEARENA_NF009R-NF009G_Camera4     collar         RG
# 680   112724_COOPTRAIN_LARGEARENA_NF031R-NF031G_Camera3     collar         RG
# 691   120624_COOPTRAIN_LARGEARENA_NM028R-NM028G_Camera2     collar         RG
# 696   120624_COOPTRAIN_LARGEARENA_NM001R-NM001G_Camera2     collar         RG
# ...                                                 ...        ...        ...
# 1093  041224_COOPTRAIN_LARGEARENA_EB011Y-EB015R_Camera3       dyed         RY
# 1094  041224_COOPTRAIN_LARGEARENA_EB005Y-EB007R_Camera2       dyed         RY
# 1096  041224_COOPTRAIN_LARGEARENA_EB027Y-EB029R_Camera2       dyed         RY
# 1097  041224_COOPTRAIN_LARGEARENA_EB021R-EB023B_Camera1       dyed         RB
# 1098  041224_COOPTRAIN_LARGEARENA_EB001R-EB003B_Camera1       dyed         RB
#
#       tracked     error  lever   mag  event id  fiber pho
# 677      True  0.102956   True  True      True      False
# 678      True  0.114880   True  True      True      False
# 680      True  0.180955   True  True      True      False
# 691      True  0.180186   True  True      True      False
# 696      True  0.129501   True  True      True      False
# ...       ...       ...    ...   ...       ...        ...
# 1093     True  0.002566   True  True      True      False
# 1094     True  0.005218   True  True      True      False
# 1096     True  0.005213   True  True      True      False
# 1097     True  0.004507   True  True      True      False
# 1098     True  0.002757   True  True      True      False
#
# [188 rows x 11 columns]

# %%
df[(df['tracked']) & (df['dir'] == 'Training_COOP_Fiber_new')]
# Out:
#                          dir session  \
# 390  Training_COOP_Fiber_new  060525
# 395  Training_COOP_Fiber_new  060525
# 398  Training_COOP_Fiber_new  060525
# 399  Training_COOP_Fiber_new  060525
# 407  Training_COOP_Fiber_new  062325
# ..                       ...     ...
# 650  Training_COOP_Fiber_new  060425
# 653  Training_COOP_Fiber_new  061325
# 657  Training_COOP_Fiber_new  061325
# 663  Training_COOP_Fiber_new  061325
# 665  Training_COOP_Fiber_new  061325
#
#                                                  video color type color pair  \
# 390  060525_COOPTRAIN_LARGEARENA_KM018B-KM018Y_Sess...     collar         YB
# 395  060525_COOPTRAIN_LARGEARENA_KM017R-KM017G_Sess...     collar         RG
# 398  060525_COOPTRAIN_LARGEARENA_KM017G-KM017R_Sess...     collar         RG
# 399  060525_COOPTRAIN_LARGEARENA_KM018Y-KM018B_Sess...     collar         YB
# 407  062325_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...     collar         RG
# ..                                                 ...        ...        ...
# 650  060425_COOPTRAIN_LARGEARENA_KM018Y-KM018B_Sess...     collar         YB
# 653  061325_COOPTRAIN_LARGEARENA_FIBER_KM017R-KM017...     collar         RG
# 657  061325_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...     collar         RG
# 663  061325_COOPTRAIN_LARGEARENA_FIBER_KM018Y-KM018...     collar         YB
# 665  061325_COOPTRAIN_LARGEARENA_FIBER_KM018B-KM018...     collar         YB
#
#      tracked     error  lever    mag  event id  fiber pho
# 390     True  0.443872  False  False     False      False
# 395     True  0.429228  False  False     False      False
# 398     True  0.387858  False  False     False      False
# 399     True  0.368364  False  False     False      False
# 407     True  0.276324  False  False     False      False
# ..       ...       ...    ...    ...       ...        ...
# 650     True  0.349123  False  False     False      False
# 653     True  0.439546  False  False     False      False
# 657     True  0.382752  False  False     False      False
# 663     True  0.445162  False  False     False      False
# 665     True  0.455346  False  False     False      False
#
# [79 rows x 11 columns]

# %%
df[(df['error'] < 0.2) & (df['dir'] == 'Training_COOP_Fiber_new')]
# Out:
#                          dir session  \
# 466  Training_COOP_Fiber_new  062525
# 519  Training_COOP_Fiber_new  062625
# 630  Training_COOP_Fiber_new  061925
#
#                                                  video color type color pair  \
# 466  062525_COOPTRAIN_LARGEARENA_FIBER_KM017R-KM017...     collar         RG
# 519  062625_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...     collar         RG
# 630  061925_COOPTRAIN_LARGEARENA_FIBER_KM017R-KM017...     collar         RG
#
#      tracked     error  lever    mag  event id  fiber pho
# 466     True  0.193206  False  False     False      False
# 519     True  0.143289  False  False     False      False
# 630     True  0.154535  False  False     False      False

# %%
error = np.array(df[(df['tracked']) & (df['dir'] == 'Training_COOP_Fiber')]['error'])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(error)
# Out:
# (array([ 3.,  6.,  7., 12., 12., 13., 17.,  4.,  3.,  2.]),
#  array([0.14328877, 0.1937271 , 0.24416543, 0.29460377, 0.3450421 ,
#         0.39548043, 0.44591877, 0.4963571 , 0.54679544, 0.59723377,
#         0.6476721 ]),
#  <BarContainer object of 10 artists>)

# %%
df[(df['error'] < .2) & (df['dir'] == 'Training_COOP_Fiber')]
# Out:
#                      dir session  \
# 466  Training_COOP_Fiber  062525
# 519  Training_COOP_Fiber  062625
# 630  Training_COOP_Fiber  061925
#
#                                                  video color type color pair  \
# 466  062525_COOPTRAIN_LARGEARENA_FIBER_KM017R-KM017...     collar         RG
# 519  062625_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...     collar         RG
# 630  061925_COOPTRAIN_LARGEARENA_FIBER_KM017R-KM017...     collar         RG
#
#      tracked     error  lever    mag  event id  fiber pho
# 466     True  0.193206  False  False     False      False
# 519     True  0.143289  False  False     False      False
# 630     True  0.154535  False  False     False      False

# %%
df[(df['dir'] == 'Training_COOPERATION') & ((~df['lever']) | (~df['mag']))]
# Out:
#                        dir session  \
# 676   Training_COOPERATION  111924
# 682   Training_COOPERATION  112724
# 683   Training_COOPERATION  112724
# 686   Training_COOPERATION  112724
# 688   Training_COOPERATION  112724
# 693   Training_COOPERATION  120624
# 694   Training_COOPERATION  120624
# 706   Training_COOPERATION  020425
# 724   Training_COOPERATION  120224
# 727   Training_COOPERATION  120224
# 729   Training_COOPERATION  120224
# 760   Training_COOPERATION  041524
# 767   Training_COOPERATION  042324
# 808   Training_COOPERATION  112624
# 812   Training_COOPERATION  112624
# 820   Training_COOPERATION  120524
# 822   Training_COOPERATION  120524
# 833   Training_COOPERATION  111424
# 849   Training_COOPERATION  020625
# 861   Training_COOPERATION  041824
# 870   Training_COOPERATION  041424
# 913   Training_COOPERATION  012425
# 926   Training_COOPERATION  112524
# 939   Training_COOPERATION  120424
# 968   Training_COOPERATION  042924
# 969   Training_COOPERATION  042924
# 970   Training_COOPERATION  042924
# 971   Training_COOPERATION  042924
# 986   Training_COOPERATION  042524
# 987   Training_COOPERATION  042524
# 1030  Training_COOPERATION  120324
# 1034  Training_COOPERATION  120324
# 1095  Training_COOPERATION  041224
# 1099  Training_COOPERATION  041224
#
#                                                   video color type color pair  \
# 676   111924_COOPTRAIN_LARGEARENA_NF019R-NF019G_Camera4     collar         RG
# 682   112724_COOPTRAIN_LARGEARENA_NM003R-NM003G_Camera2     collar         RG
# 683   112724_COOPTRAIN_LARGEARENA_NM014B-NM014Y_Camera2     collar         YB
# 686   112724_COOPTRAIN_LARGEARENA_NM001R-NM001G_Camera1     collar         RG
# 688   112724_COOPTRAIN_LARGEARENA_NM028R-NM028G_Camera2     collar         RG
# 693   120624_COOPTRAIN_LARGEARENA_NM014B-NM014Y_Camera1     collar         YB
# 694   120624_COOPTRAIN_LARGEARENA_NF019R-NF019G_Camera4     collar         RG
# 706   020425_COOPTRAIN_LARGEARENA_KM012R-KM012G_Camera2     collar         RG
# 724   120224_COOPTRAIN_LARGEARENA_NF019R-NF019G_Camera3     collar         RG
# 727   120224_COOPTRAIN_LARGEARENA_NM001R-NF001G_Camera2     collar         RG
# 729   120224_COOPTRAIN_LARGEARENA_NM015R-NM015G_Camera2     collar         RG
# 760   041524_COOPTRAIN_LARGEARENA_EB027Y-EB029R_Camera4       dyed         RY
# 767   042324_COOPTRAIN_LARGEARENA_EB003B-EB019Y_Camera2       dyed         YB
# 808   112624_COOPTRAIN_LARGEARENA_NM014B-NM014Y_Camera2     collar         YB
# 812   112624_COOPTRAIN_LARGEARENA_NM003R-NM003G_Camera2     collar         RG
# 820   120524_COOPTRAIN_LARGEARENA_NM028R-NM028G_Camera2     collar         RG
# 822   120524_COOPTRAIN_LARGEARENA_NM003R-NM003G_Camera1     collar         RG
# 833   111424_COOPTRAIN_LARGEARENA_NM006B-NM006Y_Camera1     collar         YB
# 849   020625_COOPTRAIN_LARGEARENA_KM012R-KM012G_Camera1     collar         RG
# 861   041824_COOPTRAIN_LARGEARENA_EB009B-EB033Y_Camera3       dyed         YB
# 870   041424_COOPTRAIN_LARGEARENA_EB009B-EB019Y_Camera2       dyed         YB
# 913   012425_COOPTRAIN_LARGEARENA_NF030B-NF030Y_Camera3     collar         YB
# 926   112524_COOPTRAIN_LARGEARENA_NM003R-NM003G_Camera2     collar         RG
# 939   120424_COOPTRAIN_LARGEARENA_NM003R-NM003G_Camera2     collar         RG
# 968   042924_COOPTRAIN_LARGEARENA_EB005Y-EB007R_Camera1       dyed         RY
# 969   042924_COOPTRAIN_LARGEARENA_EB021R-EB023B_Camera3       dyed         RB
# 970   042924_COOPTRAIN_LARGEARENA_EB027Y-EB029R_Camera4       dyed         RY
# 971   042924_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...       dyed         RB
# 986   042524_COOPTRAIN_LARGEARENA_EB009B-EB033Y_Camera3       dyed         YB
# 987   042524_COOPTRAIN_LARGEARENA_EB003B-EB019Y_Camera2       dyed         YB
# 1030  120324_COOPTRAIN_LARGEARENA_NM028R-NM028G_Camera1     collar         RG
# 1034  120324_COOPTRAIN_LARGEARENA_NM014B-NM014Y_Camera1     collar         YB
# 1095  041224_COOPTRAIN_LARGEARENA_EB009B-EB019Y_Camera4       dyed         YB
# 1099  041224_COOPTRAIN_LARGEARENA_EB031B-EB033Y_Camera3       dyed         YB
#
#       tracked     error  lever    mag  event id  fiber pho
# 676      True  0.309889   True  False      True      False
# 682      True  0.125144   True  False      True      False
# 683      True  0.299754   True  False      True      False
# 686      True  0.236826   True  False      True      False
# 688      True  0.372874   True  False      True      False
# 693      True  0.520805   True  False      True      False
# 694      True  0.214149   True  False      True      False
# 706      True  0.147135   True  False      True      False
# 724      True  0.245700  False  False     False      False
# 727      True  0.126806  False  False     False      False
# 729      True  0.093557   True  False      True      False
# 760      True  0.004222   True  False      True      False
# 767      True  0.003944   True  False      True      False
# 808      True  0.337788   True  False      True      False
# 812      True  0.218552   True  False      True      False
# 820      True  0.157856   True  False      True      False
# 822      True  0.252497  False  False     False      False
# 833      True  0.345004  False  False     False      False
# 849      True  0.131275  False  False     False      False
# 861      True  0.002947   True  False      True      False
# 870      True  0.303040   True  False      True      False
# 913      True  0.381279   True  False      True      False
# 926      True  0.144684   True  False      True      False
# 939      True  0.185673  False  False     False      False
# 968      True  0.003185  False  False     False      False
# 969      True  0.001046  False  False     False      False
# 970      True  0.004640  False  False     False      False
# 971      True  0.001270  False  False     False      False
# 986      True  0.002705   True  False      True      False
# 987      True  0.004455   True  False      True      False
# 1030     True  0.293314   True  False      True      False
# 1034     True  0.371323   True  False      True      False
# 1095     True  0.362437   True  False      True      False
# 1099     True  0.004061   True  False      True      False

# %%
df[(df['lever']) & (df['mag'])]
# Out:
#                        dir                              session  \
# 3    PairedTestingSessions                 041824_KL007_TimeOut
# 4    PairedTestingSessions                 041824_KL007_TimeOut
# 5    PairedTestingSessions  051424_EB005Y-007R-009B_TimeOut_VEH
# 11   PairedTestingSessions  053124_EB011Y-015R-017B_TimeOut_CNO
# 12   PairedTestingSessions  053124_EB011Y-015R-017B_TimeOut_CNO
# ..                     ...                                  ...
# 384  PairedTestingSessions  052924_EB029R-027Y-023B_TimeOut_CNO
# 385  PairedTestingSessions  051524_EB007R-005Y-027Y_TimeOut_VEH
# 386  PairedTestingSessions  051524_EB007R-005Y-027Y_TimeOut_VEH
# 387  PairedTestingSessions  051324_EB015R-011Y-003B_TimeOut_VEH
# 388  PairedTestingSessions  051324_EB015R-011Y-003B_TimeOut_VEH
#
#                                       video color type color pair  tracked  \
# 3    041824_Cam3_TrNum11_Coop_KL007Y-KL007G       dyed         GY     True
# 4     041824_Cam3_TrNum5_Coop_KL007Y-KL007G       dyed         GY     True
# 5     051424_Cam4_TrNum9_Coop_EB005Y-EB007R       dyed         RY     True
# 11    053124_Cam4_TrNum8_Coop_EB011Y-EB015R       dyed         RY     True
# 12   053124_Cam4_TrNum10_Coop_EB011Y-EB017B       dyed         YB     True
# ..                                      ...        ...        ...      ...
# 384   052924_Cam1_TrNum7_Coop_EB029R-EB027Y       dyed         RY     True
# 385  051524_Cam2_TrNum11_Coop_EB007R-EB027Y       dyed         RY     True
# 386   051524_Cam2_TrNum7_Coop_EB007R-EB005Y       dyed         RY     True
# 387   051324_Cam3_TrNum8_Coop_EB015R-EB011Y       dyed         RY     True
# 388  051324_Cam3_TrNum12_Coop_EB015R-EB003B       dyed         RB     True
#
#         error  lever   mag  event id  fiber pho
# 3    0.006750   True  True      True      False
# 4    0.005204   True  True      True      False
# 5    0.004351   True  True      True      False
# 11   0.000229   True  True      True      False
# 12   0.001263   True  True      True      False
# ..        ...    ...   ...       ...        ...
# 384  0.002312   True  True      True      False
# 385  0.002231   True  True      True      False
# 386  0.003494   True  True      True      False
# 387  0.000518   True  True      True      False
# 388  0.000804   True  True      True      False
#
# [278 rows x 11 columns]

# %%
df[(df['error'] < .2) & (df['lever']) & (df['mag'])]
# Out:
#                        dir                              session  \
# 3    PairedTestingSessions                 041824_KL007_TimeOut
# 4    PairedTestingSessions                 041824_KL007_TimeOut
# 5    PairedTestingSessions  051424_EB005Y-007R-009B_TimeOut_VEH
# 11   PairedTestingSessions  053124_EB011Y-015R-017B_TimeOut_CNO
# 12   PairedTestingSessions  053124_EB011Y-015R-017B_TimeOut_CNO
# ..                     ...                                  ...
# 384  PairedTestingSessions  052924_EB029R-027Y-023B_TimeOut_CNO
# 385  PairedTestingSessions  051524_EB007R-005Y-027Y_TimeOut_VEH
# 386  PairedTestingSessions  051524_EB007R-005Y-027Y_TimeOut_VEH
# 387  PairedTestingSessions  051324_EB015R-011Y-003B_TimeOut_VEH
# 388  PairedTestingSessions  051324_EB015R-011Y-003B_TimeOut_VEH
#
#                                       video color type color pair  tracked  \
# 3    041824_Cam3_TrNum11_Coop_KL007Y-KL007G       dyed         GY     True
# 4     041824_Cam3_TrNum5_Coop_KL007Y-KL007G       dyed         GY     True
# 5     051424_Cam4_TrNum9_Coop_EB005Y-EB007R       dyed         RY     True
# 11    053124_Cam4_TrNum8_Coop_EB011Y-EB015R       dyed         RY     True
# 12   053124_Cam4_TrNum10_Coop_EB011Y-EB017B       dyed         YB     True
# ..                                      ...        ...        ...      ...
# 384   052924_Cam1_TrNum7_Coop_EB029R-EB027Y       dyed         RY     True
# 385  051524_Cam2_TrNum11_Coop_EB007R-EB027Y       dyed         RY     True
# 386   051524_Cam2_TrNum7_Coop_EB007R-EB005Y       dyed         RY     True
# 387   051324_Cam3_TrNum8_Coop_EB015R-EB011Y       dyed         RY     True
# 388  051324_Cam3_TrNum12_Coop_EB015R-EB003B       dyed         RB     True
#
#         error  lever   mag  event id  fiber pho
# 3    0.006750   True  True      True      False
# 4    0.005204   True  True      True      False
# 5    0.004351   True  True      True      False
# 11   0.000229   True  True      True      False
# 12   0.001263   True  True      True      False
# ..        ...    ...   ...       ...        ...
# 384  0.002312   True  True      True      False
# 385  0.002231   True  True      True      False
# 386  0.003494   True  True      True      False
# 387  0.000518   True  True      True      False
# 388  0.000804   True  True      True      False
#
# [197 rows x 11 columns]

# %%
df[(~df['tracked'] | (df['error'] > 0.2)) & (df['color type'] == 'collar')]
# Out:
#                         dir  \
# 0     PairedTestingSessions
# 1     PairedTestingSessions
# 2     PairedTestingSessions
# 6     PairedTestingSessions
# 7     PairedTestingSessions
# ...                     ...
# 1049   Training_COOPERATION
# 1051   Training_COOPERATION
# 1055   Training_COOPERATION
# 1057   Training_COOPERATION
# 1058   Training_COOPERATION
#
#                                                 session  \
# 0     022125_PairedTesting_TimeOut_DREADD_KM010-KM01...
# 1     022125_PairedTesting_TimeOut_DREADD_KM010-KM01...
# 2     022125_PairedTesting_TimeOut_DREADD_KM010-KM01...
# 6     022525_PairedTesting_TimeOut_DREADD_KL013-KM01...
# 7     022525_PairedTesting_TimeOut_DREADD_KL013-KM01...
# ...                                                 ...
# 1049                                             112024
# 1051                                             010925
# 1055                                             012725
# 1057                                             012725
# 1058                                             012725
#
#                                                   video color type color pair  \
# 0         022125_Cam1_TrNum8_Coop_KM010Y-KM015G_DCZ-SAL     collar         GY
# 1         022125_Cam1_TrNum9_Coop_KM010B-KM010Y_DCZ-DCZ     collar         YB
# 2         022125_Cam1_TrNum7_Coop_KM010B-KM015G_DCZ-SAL     collar         GB
# 6         022525_Cam1_TrNum6_Coop_KM013R-KL016B_SAL-SAL     collar         RB
# 7         022525_Cam1_TrNum4_Coop_KM013G-KM016B_SA2-SAL     collar         GB
# ...                                                 ...        ...        ...
# 1049  112024_COOPTRAIN_LARGEARENA_NF019R-NF019G_Camera3     collar         RG
# 1051  010925_COOPTRAIN_LARGEARENA_NF033B-NF033R_Camera3     collar         RB
# 1055  012725_COOPTRAIN_LARGEARENA_KM009R-KM009G_Camera2     collar         RG
# 1057  012725_COOPTRAIN_LARGEARENA_NF021R-NF021G_Camera4     collar         RG
# 1058  012725_COOPTRAIN_LARGEARENA_NF030B-NF030Y_Camera3     collar         YB
#
#       tracked     error  lever    mag  event id  fiber pho
# 0       False       NaN  False  False     False      False
# 1        True  0.415569  False  False     False      False
# 2       False       NaN  False  False     False      False
# 6       False       NaN  False  False     False      False
# 7       False       NaN  False  False     False      False
# ...       ...       ...    ...    ...       ...        ...
# 1049     True  0.299496  False  False     False      False
# 1051    False       NaN  False  False     False      False
# 1055     True  0.277423  False  False     False      False
# 1057     True  0.309543  False  False     False      False
# 1058     True  0.385155  False  False     False      False
#
# [508 rows x 11 columns]

# %%
np.unique(df[~df['tracked']]['color type'])
# Out:
# array(['collar', 'dyed'], dtype=object)

# %%
new_df = df.drop(['lever', 'mag', 'event id', 'fiber pho'], axis=1)

# %%
new_df.to_csv('all_coop_vid.csv', index=False)

# %%
import os

# %%
sessions = os.listdir('/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/')
for sesh in sessions:
    try:
        levers = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/processed/lever/')
        mags = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/processed/mag/')
        videos = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Videos/')
        for lev in levers:
            animal_id = lev.split("_")
            vid = [x for x in videos if animal_id[0] in x and animal_id[1] in x]
            if len(vid) == 1:
                print(f'mv {sesh}/Behavioral/processed/lever/{lev} {sesh}/Behavioral/processed/lever/{vid[0].split('.')[0]}_lever.csv')
            else:
                print(lev, videos)
                raise Exception
        for mag in mags:
            animal_id = mag.split("_")
            vid = [x for x in videos if animal_id[0] in x and animal_id[1] in x]
            if len(vid) == 1:
                print(f'mv {sesh}/Behavioral/processed/mag/{mag} {sesh}/Behavioral/processed/mag/{vid[0].split('.')[0]}_mag.csv')
            else:
                print(mag, videos)
                raise Exception
    except:
        # print("BAD HERE", sesh)
        continue

# %%
BAD HERE 043025
BAD HERE 021225
BAD HERE 051225
BAD HERE behav_more
BAD HERE 032725
BAD HERE save_file.mlx
BAD HERE 031825
BAD HERE 121124
BAD HERE 021125
BAD HERE 011725
# Out:
# '021325'
