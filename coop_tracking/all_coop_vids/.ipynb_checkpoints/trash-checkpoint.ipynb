# %%
# make data frame with all coop vids, figure out what models we need
# write reusable and well commented code...?

# %%
# PairedTestingSessions, Training_COOP_Fiber, Training_COOPERATION

# Session name
    # Behavioral
        # processed
            # lever
            # mag
    # Tracking
        # h5
        # slp
    # Videos
    # Neuronal

# %%
import os
import pandas as pd
import numpy as np

# %%
all_folds = os.listdir('/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/')

# %%
for fold in all_folds:
    date = fold[:6]
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}')
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Videos'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Videos')
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral')
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Tracking'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Tracking')
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral/processed'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral/processed')
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Tracking/slp'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Tracking/slp')
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Tracking/h5'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Tracking/h5')
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral/processed/lever'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral/processed/lever')
    if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral/processed/mag'):
        os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral/processed/mag')

# %%
for fold in all_folds:
    date = fold[:6]
    files = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber_old/{fold}')
    for file in files:
        if '.mp4' in file: 
            print(f'cp /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber_old/{fold}/{file} /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Videos/{file}')
        elif '.h5' in file:
            print(f'cp /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber_old/{fold}/{file} /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Tracking/h5/{file}')
        elif '.slp' in file:
            print(f'cp /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber_old/{fold}/{file} /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Tracking/slp/{file}')
        else:
            print(f'cp /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber_old/{fold}/{file} /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{date}/Behavioral/{file}')

# %%
# check that copying works by making sure we have same number of videos in both folder! 
# (training coop fiber and training coop fiber old)

# %%
vid_count_new = []
vid_count_old = []

sessions = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber_old/')
for sesh in sessions:
    files = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber_old/{sesh}')
    vids = [x for x in files if 'mp4' in x]
    vid_count_old.append(vids)

sessions = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/')
for sesh in sessions:
    files = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Videos')
    vid_count_new.append(files)
# print(vid_count_new, vid_count_old)

bad = [x for x in vid_count_old if x not in vid_count_new]

# %%
single_list_new = [item for sublist in vid_count_new for item in sublist]
single_list_old = [item for sublist in vid_count_old for item in sublist]

# %%
bad = [x for x in single_list_old if x not in single_list_new]

# %%
bad
# Out:
# ['061325_COOPTRAIN_LARGEARENA_FIBER_KM017R-KM017G_Cam1_SessNum 4_Camera1.mp4']

# %%
sessions = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/')
for sesh in sessions:
    files = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Tracking/h5')
    for f in files:
        print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Tracking/h5/{f} /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Tracking/h5/{f.split('.')[0]}.predictions.h5')
    files = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Tracking/slp')
    for f in files:
        print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Tracking/slp/{f} /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Tracking/slp/{f.split('.')[0]}.predictions.slp')
    vid_count_new.append(files)
# print(vid_count_new, vid_count_old)

# %%
sessions = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/')
for sesh in sessions:
    if len(sesh) == 6:
        # if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Videos'):
        #     os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Videos')
        # if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/processed'):
        #     if not os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral'):
        #         os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral')
        #     os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/processed')

        # if os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/lever'):
        #     print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/lever /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/processed/lever')

        # if os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/mag'):
        #     print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/mag /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/processed/mag')


        files = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}')
        files = [x for x in files if not os.path.isdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/{x}')]
        for file in files:
            if '.mp4' in file: 
                print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/{file} /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Videos/{file}')
            elif '.h5' in file:
                print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/{file} /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Tracking/h5/{file}')
            elif '.slp' in file:
                print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/{file} /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Tracking/slp/{file}')
            else:
                print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/{file} /gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/Behavioral/{file}')

# %%
files = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}')
files = [x for x in files if not os.path.isdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}/{x}')]
sesh, files
# Out:
# ('043025',
#  ['043025_COOPTRAIN_LARGEARENA_NF008B-NF008Y_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF019R-NF019G_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF017R-NF017G_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF009R-NF009G_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF021R-NF021G_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF010B-NF010Y_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF020B-NF020Y_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF018B-NF018Y_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF031G-NF031R_loaded_loaded_loaded',
#   '043025_COOPTRAIN_LARGEARENA_NF032Y-NF032B_loaded_loaded_loaded'])

# %%
os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}')
# Out:
# False

# %%
os.path.exists(f'/gpfs/radev/pi/saxena/aj764/Training_COOPERATION/{sesh}')
# Out:
# False

# %%
sesh
# Out:
# '060525'

# %%
# do neural data for fiber coop fiber because I think you messed this up (this is what mat files are!!)
sessions = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/')
for sesh in sessions:
    os.mkdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Neuronal')
    files = os.listdir(f'/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Behavioral')
    files = [x for x in files if '.mat' in x]
    for f in files:
        print(f'mv /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Behavioral/{f} /gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/{sesh}/Neuronal/{f}')

# %%
import sleap_io as sio
import os

# %%
def split_sleap_labels_by_video(input_path: str, output_dir: str):
    """
    Splits a single SLEAP project file containing multiple videos into
    separate project files, one for each video.

    Args:
        input_path: Path to the combined .slp project file.
        output_dir: Directory where the new .slp files will be saved.
    """
    # Load the main project file
    try:
        labels = sio.load_file(input_path)
    except Exception as e:
        print(f"Error loading {input_path}: {e}")
        return

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Group labeled frames by video filename
    labels_by_video = {}
    for lf in labels.labeled_frames:
        video_filename = lf.video.filename
        if video_filename not in labels_by_video:
            labels_by_video[video_filename] = sio.Labels(
                videos=[lf.video],
                skeletons=labels.skeletons
            )
        labels_by_video[video_filename].labeled_frames.append(lf)

    # Save each video's labels to a new project file
    for video_filename, video_labels in labels_by_video.items():
        base_name = os.path.splitext(os.path.basename(video_filename))[0]
        output_path = os.path.join(output_dir, f"{base_name}.slp")
        
        try:
            sio.save_file(video_labels, output_path)
            print(f"Successfully saved labels for video '{video_filename}' to '{output_path}'.")
        except Exception as e:
            print(f"Error saving labels for video '{video_filename}': {e}")

# Example usage:
# Replace with the path to your SLEAP project file
input_slp_file = "/gpfs/radev/pi/saxena/aj764/Nina_Model_Testing/Fiber/labels.v001.slp" 
output_folder = "/gpfs/radev/pi/saxena/aj764/Nina_Model_Testing/"

split_sleap_labels_by_video(input_slp_file, output_folder)
# Out:
# Error saving labels for video '/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/060225_COOPTRAIN_LARGEARENA_KF023B-KF023G_SessNum1/060225_COOPTRAIN_LARGEARENA_KF023B-KF023G_SessNum1_Camera3.mp4': Track(name='connected') is not in list
# Error saving labels for video '/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/060225_COOPTRAIN_LARGEARENA_KF023G-KF023B_SessNum3/060225_COOPTRAIN_LARGEARENA_KF023G-KF023B_SessNum3_Camera4.mp4': Track(name='connected') is not in list
# Error saving labels for video '/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/060225_COOPTRAIN_LARGEARENA_KF024G-KF025Y_SessNum4/060225_COOPTRAIN_LARGEARENA_KF024G-KF025Y_SessNum4_Camera3.mp4': Track(name='connected') is not in list
# Error saving labels for video '/gpfs/radev/pi/saxena/aj764/Training_COOP_Fiber/060225_COOPTRAIN_LARGEARENA_KF024R-KF025B_SessNum2/060225_COOPTRAIN_LARGEARENA_KF024R-KF025B_SessNum2_Camera4.mp4': Track(name='disconnected') is not in list
# ...

# %%
import sleap_io as sio

# Load your manual annotations and new predictions
base_labels = sio.load_file("manual_annotations.slp")
predictions = sio.load_file("model_predictions.slp")

# Merge predictions into base project
# Default 'smart' strategy preserves manual labels
result = base_labels.merge(predictions)

# Check what happened
print(f"Frames merged: {result.frames_merged}")
print(f"Instances added: {result.instances_added}")

# Save the merged project
base_labels.save("merged_project.slp")
