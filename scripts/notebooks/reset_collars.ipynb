# %%
import pandas as pd

# %%
df = pd.read_csv('collar_preds_df.csv')

# %%
df = df[df['single/multi'] == 'multi']

# %%
from collections import Counter

# %%
Counter(df['color pair']).keys()
# Out:
# dict_keys(['YB', 'RY', 'RB', 'GY', 'GB', 'RG', 'B'])

# %%
# after I synced PairedTestingSessions
# dict_values([117, 12, 20, 13, 14, 156, 10])
Counter(df['color pair']).values()
# Out:
# dict_values([117, 12, 20, 13, 14, 156, 10])

# %%
# before I synced PairedTestingSessions
# dict_values([92, 10, 10, 10, 10, 105, 10])
Counter(df['color pair']).values()
# Out:
# dict_values([92, 10, 10, 10, 10, 105, 10])
