# %%
# starting over because I've confused my self yay!

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import h5py
import seaborn as sns
from scipy.stats import ttest_ind

import sys
sys.path.append('../../../')

from src.utils.error_utils import get_nan_prec
from utils2 import get_dist_frames

node = 3 # ['nose','earL','earR','headBase','foreLimbL','foreLimbR','hindLimbL','hindLimbR','tailBase','tailMid','tailTip','leverTop','leverBottom','magTop','magBottom']

# %%
root = '/gpfs/radev/pi/saxena/aj764/Training_LARGEARENA_Individual/'
sessions = os.listdir(root)

# %%
df = pd.DataFrame(columns=['vid', 'session', 'animal id', 'month', 'day', 'year'])

# %%
# get all of the videos from large arean training
index = 0
for s in sessions:
    if os.path.isdir(root + s):
        files = os.listdir(root + s)
        files = [f[:-4] for f in files if 'mp4' in f]
        for f in files:
            if os.path.exists(root + s + '/Tracking/h5_not_corrected/' + f + 'predictions.h5'):
                animal_id = f.split('_')[3]
            
                month, day, year = f[:2], f[2:4], f[4:6]
                df.loc[index] = [f, s, animal_id, month, day, year]
                index += 1
    
    # get initial nan, get corrected nan, get animal id
    # sort by animal id
    # see how many vids each animal has
    # see how many good vids each animal has
    # focus on kl and eb!

# %%
# sort videos by date and only take videos from the EB and KL cohorts
id_df = df.sort_values(by=['animal id', 'year', 'month', 'day'])
id_df = id_df[id_df['animal id'].str.contains('EB') | id_df['animal id'].str.contains('KL')]
id_df['animal group'] = id_df['animal id'].apply(lambda x: 'EB' if 'EB' in x else ('KL' if 'KL' in x else 'Unknown'))

# %%
id_df
# Out:
#                                            vid session animal id month day  \
# 886    032624_ISTRAIN_LARGEARENA_EB001_Camera4  032624     EB001    03  26
# 1259  032524_ISTRAIN_LARGEARENA_EB001R_Camera1  032524    EB001R    03  25
# 155   032824_ISTRAIN_LARGEARENA_EB001R_Camera1  032824    EB001R    03  28
# 1213  032924_ISTRAIN_LARGEARENA_EB001R_Camera1  032924    EB001R    03  29
# 962   033024_ISTRAIN_LARGEARENA_EB001R_Camera1  033024    EB001R    03  30
# ...                                        ...     ...       ...   ...  ..
# 195   032424_PVTRAIN_LARGEARENA_KL008Y_Camera4  032424    KL008Y    03  24
# 1252  032524_PVTRAIN_LARGEARENA_KL008Y_Camera4  032524    KL008Y    03  25
# 885   032624_PVTRAIN_LARGEARENA_KL008Y_Camera3  032624    KL008Y    03  26
# 495   032724_PVTRAIN_LARGEARENA_KL008Y_Camera3  032724    KL008Y    03  27
# 185   032824_PVTRAIN_LARGEARENA_KL008Y_Camera2  032824    KL008Y    03  28
#
#      year animal group
# 886    24           EB
# 1259   24           EB
# 155    24           EB
# 1213   24           EB
# 962    24           EB
# ...   ...          ...
# 195    24           KL
# 1252   24           KL
# 885    24           KL
# 495    24           KL
# 185    24           KL
#
# [367 rows x 7 columns]

# %%
for index, row in id_df.iterrows():
    with h5py.File(root + row['session'] + '/Tracking/h5_not_corrected/' + row['vid'] + 'predictions.h5','r') as f:
        locations = f["tracks"][:].T
        id_df.at[index, 'total'] = locations.shape[0]
        id_df.at[index, 'nan'] = np.sum(np.isnan(np.sum(locations[:, node, :, :], axis=1)))
        id_df.at[index, 'not nan'] = id_df.loc[index, 'total'] - id_df.loc[index, 'nan']
        id_df.at[index, 'center'] = len(get_dist_frames('center', locations, node))
        id_df.at[index, 'wall'] = len(get_dist_frames('wall', locations, node))
        id_df.at[index, 'corner'] = len(get_dist_frames('corner', locations, node))

        id_df.at[index, 'nan prec'] = 100 * id_df.loc[index, 'nan'] / id_df.loc[index, 'total']
        id_df.at[index, 'center prec'] = 100 * id_df.loc[index, 'center'] / id_df.loc[index, 'total']
        id_df.at[index, 'norm center prec'] = 100 * id_df.loc[index, 'center'] / id_df.loc[index, 'not nan']
        id_df.at[index, 'wall prec'] = 100 * id_df.loc[index, 'wall'] / id_df.loc[index, 'total']
        id_df.at[index, 'norm wall prec'] = 100 * id_df.loc[index, 'wall'] / id_df.loc[index, 'not nan']
        id_df.at[index, 'corner prec'] = 100 * id_df.loc[index, 'corner'] / id_df.loc[index, 'total']
        id_df.at[index, 'norm corner prec'] = 100 * id_df.loc[index, 'corner'] / id_df.loc[index, 'not nan']
# Out:
# /tmp/ipykernel_1771910/3198991346.py:13: RuntimeWarning: divide by zero encountered in scalar divide
#   id_df.at[index, 'norm center prec'] = 100 * id_df.loc[index, 'center'] / id_df.loc[index, 'not nan']
# /tmp/ipykernel_1771910/3198991346.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   id_df.at[index, 'norm wall prec'] = 100 * id_df.loc[index, 'wall'] / id_df.loc[index, 'not nan']
# /tmp/ipykernel_1771910/3198991346.py:17: RuntimeWarning: divide by zero encountered in scalar divide
#   id_df.at[index, 'norm corner prec'] = 100 * id_df.loc[index, 'corner'] / id_df.loc[index, 'not nan']

# %%
id_df[id_df['animal id'] == 'EB003']
# Out:
#                                          vid session animal id month day year  \
# 898  032624_ISTRAIN_LARGEARENA_EB003_Camera4  032624     EB003    03  26   24
# 521  032724_ISTRAIN_LARGEARENA_EB003_Camera4  032724     EB003    03  27   24
#
#     animal group     total      nan  not nan   center     wall   corner  \
# 898           EB      37.0     37.0      0.0     23.0     23.0     23.0
# 521           EB  108006.0  54589.0  53417.0  10069.0  44209.0  27929.0
#
#        nan prec  center prec  norm center prec  wall prec  norm wall prec  \
# 898  100.000000    62.162162               inf  62.162162             inf
# 521   50.542562     9.322630         18.849804  40.931985       82.762042
#
#      corner prec  norm corner prec
# 898    62.162162               inf
# 521    25.858749         52.284853

# %%
unique_ids = sorted(list(set(id_df['animal id'])))

# %%
len(unique_ids)
# Out:
# 84

# %%
for ids in unique_ids:
    if id_df[id_df['animal id'] == ids].shape[0] > 1 and ids != 'EB003': # one of these vids has 100% nan...
        animal_df = id_df[id_df['animal id'] == ids]
        first = animal_df.head(1)
        last = animal_df.tail(1)
        id_df.at[first.index.item(), 'order'] = 'first'
        id_df.at[last.index.item(), 'order'] = 'last'

# %%
list(id_df.columns)[14:-1]
# Out:
# ['center prec',
#  'norm center prec',
#  'wall prec',
#  'norm wall prec',
#  'corner prec']

# %%
 with h5py.File(root + '032524' + '/Tracking/h5_not_corrected/' + '032524_ISTRAIN_LARGEARENA_EB005Y_Camera3' + 'predictions.h5','r') as f:
        locations = f["tracks"][:].T

# %%
locations.shape[0], np.sum(np.isnan(locations[:, node, :, :])) // 2
# Out:
# (98201, 41894)

# %%
maxdist = 100

# %%
xmin, xmax = np.nanmin(locations[:, node, 0, :]), np.nanmax(locations[:, node, 0, :])
ymin, ymax = np.nanmin(locations[:, node, 1, :]), np.nanmax(locations[:, node, 1, :])
sides = [xmin, xmax, ymin, ymax]
# find center
center_x, center_y = ((xmax - xmin) / 2) + xmin, ((ymax - ymin) / 2) + ymin
   
# get dist from walls
wall_dist = -1 * np.ones((locations.shape[0], 4))
for i, s in enumerate(sides):
    if i < 2:
        wall_dist[:, i] = np.abs(locations[:, node, 0, 0] - s)
    else:
        wall_dist[:, i] = np.abs(locations[:, node, 1, 0] - s)

min_wall_dist = np.min(wall_dist, axis=1)

in_area = [i for i,x in enumerate(min_wall_dist) if x < maxdist and not np.isnan(x)]
not_area = [i for i,x in enumerate(min_wall_dist) if x > maxdist and not np.isnan(x)]
# calc_final_vals(min_wall_dist, maxdist, locations, node)

# %%
len(in_area) / (locations.shape[0] - np.sum(np.isnan(np.sum(locations[:, node, :, :], axis=1))))
# Out:
# 0.7278313531177296

# %%
np.sum(np.isnan(np.sum(locations[:, node, :, :], axis=1)))# .shape
# Out:
# 41894

# %%
plt.plot(locations[not_area, node, 0, :], locations[not_area, node, 1, :], '.')
plt.plot(locations[in_area, node, 0, :], locations[in_area, node, 1, :], '.')
plt.gca().set_aspect("equal")
plt.show()

# %%
x[x['animal id'] == 'EB005Y']
# Out:
#                                            vid session animal id month day  \
# 1240  032524_ISTRAIN_LARGEARENA_EB005Y_Camera3  032524    EB005Y    03  25
#
#      year animal group    total      nan  not nan  ...     wall   corner  \
# 1240   24           EB  98201.0  41894.0  56307.0  ...  75279.0  64726.0
#
#       nan prec  center prec  norm center prec  wall prec  norm wall prec  \
# 1240  42.66148     4.442928          7.748593  76.658079      133.693857
#
#       corner prec  norm corner prec  order
# 1240    65.911752         114.95196  first
#
# [1 rows x 21 columns]

# %%
for data_name in list(id_df.columns)[14:-1]:
    x = id_df[id_df[data_name] >= 100]
    print(x.shape)
    if data_name == 'norm wall prec':
        break
# Out:
# (0, 21)
# (1, 21)
# (0, 21)
# (15, 21)

# %%
# combined
for data_name in list(id_df.columns)[14:-1]:
    order_df = id_df[(id_df['order'] == 'first') | (id_df['order'] == 'last')]
    box_colors = ['#6ac3d9', '#1f77b4']
    
    # Create the plot
    plt.figure(figsize=(8, 6))
    ax = sns.boxplot(
        x='order',
        y=data_name,
        data=order_df,
        palette=box_colors  # set custom fill colors
    )
    
    # Labeling
    plt.title(data_name)
    plt.xlabel("Cohort")
    plt.ylabel("% of time spent in area")
    
    # Get the two groups
    group1 = order_df[order_df['order'] == 'first'][data_name]
    group2 = order_df[order_df['order'] == 'last'][data_name]
    group1 = group1[group1 != np.inf]
    group2 = group2[group2 != np.inf]

    
    # Perform t-test
    t_stat, p_val = ttest_ind(group1, group2, nan_policy='omit')
    print(p_val)
    
    # Add significance annotation if p < 0.05
    if p_val < 0.05:
        # Coordinates for the bars
        x1, x2 = 0, 1
        y, h, col = max(order_df[data_name]) * 1.05, max(order_df[data_name]) * 0.05, 'k'
    
        # Draw the lines
        plt.plot([x1, x1, x2, x2], [y, y + h, y + h, y], lw=1.5, c=col)
        significance = '*' if p_val < 0.05 else 'n.s.'
        if p_val < 0.01:
            significance = '**'
        if p_val < 0.001:
            significance = '***'
        
        # Add text for significance level
        plt.text((x1 + x2) * 0.5, y + h + h * 0.1, significance, ha='center', va='bottom', color=col)
    
    plt.tight_layout()
    plt.show()
# Out:
# 0.08991594570243998
# /tmp/ipykernel_1771910/1558300466.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# /tmp/ipykernel_1771910/1558300466.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# posx and posy should be finite values
# posx and posy should be finite values
# 0.01621619322256299
# 0.06249902467765409
# /tmp/ipykernel_1771910/1558300466.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# /tmp/ipykernel_1771910/1558300466.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# 0.6074061318217894
# /tmp/ipykernel_1771910/1558300466.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# 0.1861899641983578
# /tmp/ipykernel_1771910/1558300466.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# 0.07216776906072712

# %%
id_df['order'] = ''
for data_name in list(id_df.columns)[14:]:
    data = {'kl_first': [], 'kl_last': [], 'eb_first': [], 'eb_last': []}
    for ids in unique_ids:
        if id_df[id_df['animal id'] == ids].shape[0] > 1:
            animal_df = id_df[id_df['animal id'] == ids]
            first = animal_df.head(1)
            last = animal_df.tail(1)
            id_df.at[first.index.item(), 'order'] = 'first'
            id_df.at[last.index.item(), 'order'] = 'last'
            if first['animal group'].item() == 'KL':
                data['kl_first'].append(first[data_name].item())
                data['kl_last'].append(last[data_name].item())
            else:
                data['eb_first'].append(first[data_name].item())
                data['eb_last'].append(last[data_name].item())
            # print(ids, id_df[id_df['animal id'] == ids].shape[0])
    
    # # Your dictionary
    # data = {
    #     'Group A': [1, 2, 3, 4],
    #     'Group B': [2, 3, 4, 5],
    #     'Group C': [3, 4, 5, 6]
    # }
    
    # # Convert dictionary to long-format DataFrame for seaborn
    # df = pd.DataFrame([(k, v) for k, lst in data.items() for v in lst], columns=['Group', 'Value'])
    
    # # Create box plot
    # plt.figure(figsize=(8, 6))
    # sns.boxplot(x='Group', y='Value', data=df)
    # plt.title(data_name)
    # plt.xlabel("cohort")
    # plt.ylabel("% of time spent in area")
    # plt.tight_layout()
    # plt.show()

# %%
id_df
# Out:
#                                            vid session animal id month day  \
# 886    032624_ISTRAIN_LARGEARENA_EB001_Camera4  032624     EB001    03  26
# 1259  032524_ISTRAIN_LARGEARENA_EB001R_Camera1  032524    EB001R    03  25
# 155   032824_ISTRAIN_LARGEARENA_EB001R_Camera1  032824    EB001R    03  28
# 1213  032924_ISTRAIN_LARGEARENA_EB001R_Camera1  032924    EB001R    03  29
# 962   033024_ISTRAIN_LARGEARENA_EB001R_Camera1  033024    EB001R    03  30
# ...                                        ...     ...       ...   ...  ..
# 195   032424_PVTRAIN_LARGEARENA_KL008Y_Camera4  032424    KL008Y    03  24
# 1252  032524_PVTRAIN_LARGEARENA_KL008Y_Camera4  032524    KL008Y    03  25
# 885   032624_PVTRAIN_LARGEARENA_KL008Y_Camera3  032624    KL008Y    03  26
# 495   032724_PVTRAIN_LARGEARENA_KL008Y_Camera3  032724    KL008Y    03  27
# 185   032824_PVTRAIN_LARGEARENA_KL008Y_Camera2  032824    KL008Y    03  28
#
#      year animal group     total      nan   not nan  ...     wall   corner  \
# 886    24           EB   54113.0  10662.0   43451.0  ...  20036.0   8220.0
# 1259   24           EB   94263.0  39813.0   54450.0  ...  18810.0   7133.0
# 155    24           EB  100053.0  31104.0   68949.0  ...  23879.0  10227.0
# 1213   24           EB   96867.0   4090.0   92777.0  ...  38724.0   7877.0
# 962    24           EB  107826.0   1315.0  106511.0  ...  50661.0   7637.0
# ...   ...          ...       ...      ...       ...  ...      ...      ...
# 195    24           KL   31888.0   6450.0   25438.0  ...  19283.0  16120.0
# 1252   24           KL   22403.0   2659.0   19744.0  ...  13900.0  12445.0
# 885    24           KL    8020.0   2296.0    5724.0  ...   2691.0   1060.0
# 495    24           KL   31579.0   7081.0   24498.0  ...  12924.0   9632.0
# 185    24           KL   29277.0   6928.0   22349.0  ...  15177.0  11230.0
#
#        nan prec  center prec  norm center prec  wall prec  norm wall prec  \
# 886   19.703214    12.714135         15.833928  37.026223       46.111712
# 1259  42.236084     6.811793         11.792470  19.954807       34.545455
# 155   31.087524     9.703857         14.081423  23.866351       34.632845
# 1213   4.222284    20.157536         21.046164  39.976463       41.738793
# 962    1.219557    19.850500         20.095577  46.984030       47.564101
# ...         ...          ...               ...        ...             ...
# 195   20.227045     8.369920         10.492177  60.471024       75.803915
# 1252  11.868946     6.235772          7.075567  62.045262       70.401135
# 885   28.628429     4.725686          6.621244  33.553616       47.012579
# 495   22.423129    12.508312         16.123765  40.925932       52.755327
# 185   23.663627    18.639205         24.417200  51.839328       67.909079
#
#       corner prec  norm corner prec  order
# 886     15.190435         18.917861
# 1259     7.567126         13.100092  first
# 155     10.221583         14.832702
# 1213     8.131768          8.490251
# 962      7.082707          7.170151
# ...           ...               ...    ...
# 195     50.551932         63.369762
# 1252    55.550596         63.031807
# 885     13.216958         18.518519
# 495     30.501282         39.317495
# 185     38.357755         50.248333   last
#
# [367 rows x 21 columns]
