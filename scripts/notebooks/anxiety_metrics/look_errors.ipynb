# %%
import pandas as pd

# %%
df = pd.read_csv('center_time.csv')

# %%
df[(df['first nan'] > 20)] #  | (df['last nan'] > 20)]
# Out:
#     animal id  first date  last date  first center  first not center  \
# 2      NM005R      102824      20325          6.90             36.26
# 3      NM013R      102924      20425         10.70             58.99
# 4      NM011G      102824      20425          8.29             55.15
# 5       EB010       32824      32824          8.47             64.33
# 6      NF008Y      102524      20325          5.28             45.12
# ..        ...         ...        ...           ...               ...
# 177    KL007B       32224      32824          3.13             59.07
# 178    KL001G       32224      32424          6.81             16.97
# 179     EB008       32724      32724          8.51             52.28
# 180    NF030B      121324      20525          9.18             54.50
# 182    NF031R      110424      20325          4.01             17.78
#
#      first nan  first norm center  first norm not center  first nose  \
# ...

# %%
kl = df[df['animal id'].str.contains("KL")]

# %%
eb = df[df['animal id'].str.contains("EB")]

# %%
eb[eb['first nan'] > 20]
# Out:
# (34, 17)
