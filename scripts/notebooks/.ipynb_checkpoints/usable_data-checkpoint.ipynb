# %% [markdown]
# Finds and graphs "useable" data from the dyed rats experements.

# %%
import sys
sys.path.append('../../')

# %%
from src.classes.vid_loader import VidLoader
from src.classes.pred_loader import PredLoader
import matplotlib.pyplot as plt
import numpy as np

# %%
vid = VidLoader('dyed')
# Out:
# these are how many videos there are in PairedTestingSessions/
# There are 1114 single instance videos
# There are 912 multi instance videos
# There are 128 videos from RY color pair
# There are 169 videos from YB color pair
# There are 171 videos from GB color pair
# There are 178 videos from GY color pair
# There are 99 videos from RB color pair
# There are 167 videos from RG color pair
# There are 912 multi instance videos
#
# these are how many videos there are in Training_COOPERATION/
# There are 184 multi instance videos
# There are 16 videos from GY color pair
# There are 58 videos from YB color pair
# There are 11 videos from GB color pair
# There are 21 videos from RG color pair
# There are 32 videos from RB color pair
# There are 46 videos from RY color pair
# There are 184 multi instance videos

# %%
preds = PredLoader('dyed_preds_df.csv')

# %%
print('total of cooperation trials:')
coop_df = preds.df[preds.df['trial type'] == 'coop']
print(coop_df.shape[0])

print('test cooperation trials:')
test_df = coop_df[(coop_df['test/train'] == 'test')]
print(test_df.shape[0])

print('train cooperation trials:')
train_df = coop_df[(coop_df['test/train'] == 'train')]
print(train_df.shape[0])

fig, ax = plt.subplots()
_ = ax.pie([test_df.shape[0], train_df.shape[0]], labels=['test', 'train'], startangle=90)
# Out:
# total of cooperation trials:
# 476
# test cooperation trials:
# 292
# train cooperation trials:
# 184

# %%
print('useability of test cooperation trials:')
useable = test_df[(test_df['correct'] == True) & (test_df['levers'] == True) & (test_df['mags'] == True)].shape[0]
bad_pred = test_df[(test_df['pred'] == True) & (test_df['correct'] == False) & (test_df['levers'] == True) & (test_df['mags'] == True)].shape[0]
no_pred = test_df[(test_df['pred'] == False) & (test_df['correct'] == False) & (test_df['levers'] == True) & (test_df['mags'] == True)].shape[0]
no_behav = test_df[(test_df['correct'] == True) & ((test_df['levers'] == False) | (test_df['mags'] == False))].shape[0]
both = test_df[(test_df['correct'] == False) & ((test_df['levers'] == False) | (test_df['mags'] == False))].shape[0]
fig, ax = plt.subplots()
_ = ax.pie([useable, bad_pred, no_pred, no_behav, both], labels=['useable', 'bad_pred', 'no pred', 'no behav', 'both'], startangle=90)
print([useable, bad_pred, no_pred, no_behav, both])
# Out:
# useability of test cooperation trials:
# [139, 36, 45, 2, 12]

# %%
print('useability of training cooperation trials:')
useable = train_df[(train_df['correct'] == True) & (train_df['levers'] == True) & (train_df['mags'] == True)].shape[0]
bad_pred = train_df[(train_df['pred'] == True) & (train_df['correct'] == False) & (train_df['levers'] == True) & (train_df['mags'] == True)].shape[0]
no_pred = train_df[(train_df['pred'] == False) & (train_df['correct'] == False) & (train_df['levers'] == True) & (train_df['mags'] == True)].shape[0]
no_behav = train_df[(train_df['correct'] == True) & ((train_df['levers'] == False) | (train_df['mags'] == False))].shape[0]
both = train_df[(train_df['correct'] == False) & ((train_df['levers'] == False) | (train_df['mags'] == False))].shape[0]
fig, ax = plt.subplots()
_ = ax.pie([useable, bad_pred, no_pred, no_behav, both], labels=['useable', 'bad_pred', 'no pred', 'no behav', 'both'], startangle=90)
print([useable, bad_pred, no_pred, no_behav, both])
# Out:
# useability of training cooperation trials:
# [112, 38, 11, 18, 5]

# %%
print('familiarity of useable test cooperation trials:')
useable = test_df[(test_df['correct'] == True) & (test_df['levers'] == True) & (test_df['mags'] == True)]
us_TP = useable[useable['familiarity'] == 'TP'].shape[0]
us_UF = useable[useable['familiarity'] == 'UF'].shape[0]
us_us = useable[(useable['familiarity'] != 'TP') & (useable['familiarity'] != 'UF')].shape[0]
fig, ax = plt.subplots()
_ = ax.pie([us_TP, us_UF, us_us], labels=['training partner', 'unfamiliar', 'unspecified'], startangle=90)
print([us_TP, us_UF, us_us])
# Out:
# familiarity of useable test cooperation trials:
# [65, 80, 52]

# %%
useable = test_df[(test_df['correct'] == True) & (test_df['levers'] == True) & (test_df['mags'] == True)]
fiber_pho = test_df[(test_df['fiber pho'] == True)].shape[0]
u_fiber_pho = useable[(useable['fiber pho'] == True)].shape[0]
no_fiber_pho = test_df[(test_df['fiber pho'] == False)].shape[0]
fig, ax = plt.subplots()
_ = ax.pie([u_fiber_pho, fiber_pho - u_fiber_pho, no_fiber_pho], labels=['fiber pho: useable', 'fiber pho: not useable', 'no fiber pho'], startangle=90)
print("useability of ")
print([u_fiber_pho, fiber_pho - u_fiber_pho, no_fiber_pho])
# Out:
# useability of
# [58, 46, 188]

# %%
# useable = test_df[(test_df['correct'] == True) & (test_df['levers'] == True) & (test_df['mags'] == True)]
fiber_pho = test_df[(test_df['fiber pho'] == True)]

print('useability of fiber-pho trials:')
useable = fiber_pho[(fiber_pho['correct'] == True) & (fiber_pho['levers'] == True) & (fiber_pho['mags'] == True)].shape[0]
bad_pred = fiber_pho[(fiber_pho['pred'] == True) & (fiber_pho['correct'] == False) & (fiber_pho['levers'] == True) & (fiber_pho['mags'] == True)].shape[0]
no_pred = fiber_pho[(fiber_pho['pred'] == False) & (fiber_pho['correct'] == False) & (fiber_pho['levers'] == True) & (fiber_pho['mags'] == True)].shape[0]
no_behav = fiber_pho[(fiber_pho['correct'] == True) & ((fiber_pho['levers'] == False) | (fiber_pho['mags'] == False))].shape[0]
both = fiber_pho[(fiber_pho['correct'] == False) & ((fiber_pho['levers'] == False) | (fiber_pho['mags'] == False))].shape[0]
fig, ax = plt.subplots()
_ = ax.pie([useable, bad_pred, no_pred, no_behav, both], labels=['useable', 'bad_pred', 'no pred', 'no behav', 'both'], startangle=90)
print([useable, bad_pred, no_pred, no_behav, both])
# Out:
# useability of fiber-pho trials:
# [58, 17, 21, 1, 7]

# %%
# useable = test_df[(test_df['correct'] == True) & (test_df['levers'] == True) & (test_df['mags'] == True)]
fiber_pho = test_df[(test_df['fiber pho'] == True)]

useable = fiber_pho[(fiber_pho['correct'] == True) & (fiber_pho['levers'] == True) & (fiber_pho['mags'] == True)]

bad_pred = fiber_pho[(fiber_pho['pred'] == True) & (fiber_pho['correct'] == False) & (fiber_pho['levers'] == True) & (fiber_pho['mags'] == True)]


no_pred = fiber_pho[(fiber_pho['pred'] == False) & (fiber_pho['correct'] == False) & (fiber_pho['levers'] == True) & (fiber_pho['mags'] == True)]

no_behav = fiber_pho[(fiber_pho['correct'] == True) & ((fiber_pho['levers'] == False) | (fiber_pho['mags'] == False))]
both = fiber_pho[(fiber_pho['correct'] == False) & ((fiber_pho['levers'] == False) | (fiber_pho['mags'] == False))]

# %%
# all 21 of the no pred files are from the GB pair
# the 17 bad pred files are below...
# from both there are 3 GY files that we might be able to get!
# from no behav there is 1 YB file that we might be able to get

# %%
bad_pred[bad_pred['color pair'] == 'GY'].shape[0], bad_pred[bad_pred['color pair'] == 'RY'].shape[0], bad_pred[bad_pred['color pair'] == 'YB'].shape[0], bad_pred[bad_pred['color pair'] == 'RG'].shape[0]
# Out:
# (6, 5, 4, 2)

# %%
bad_pred
# Out:
#                                          vid  \
# 1789  091124_Cam1_TrNum10_Coop_KL002Y-KL004R
# 1797   091124_Cam2_TrNum8_Coop_KL007Y-KL004R
# 1863  091824_Cam2_TrNum14_Coop_KL008G-KL001Y
# 1955  100124_Cam1_TrNum15_Coop_KL008G-KL006R
# 1964   100224_Cam2_TrNum8_Coop_KL002Y-KL006R
# 1988   101724_Cam2_TrNum5_Coop_HF004Y-HF001R
# 1990   101724_Cam2_TrNum6_Coop_HF004Y-HF003B
# 1993   101724_Cam1_TrNum6_Coop_HF008Y-HF002G
# 1998   101824_Cam2_TrNum5_Coop_KL006G-HF001R
# 1999   101824_Cam2_TrNum4_Coop_KL006G-KL008Y
# 2001   102124_Cam1_TrNum5_Coop_HF004Y-HF003B
# 2002   102124_Cam1_TrNum7_Coop_HF004Y-HF003B
# 2004   102124_Cam1_TrNum6_Coop_HF004Y-HF006G
# 2005   102124_Cam2_TrNum4_Coop_HF008Y-HF006G
# 2006   102124_Cam2_TrNum7_Coop_HF008Y-HF006G
# 2007   102124_Cam2_TrNum6_Coop_HF008Y-HF001R
# 2009   102224_Cam2_TrNum4_Coop_HF003B-HF004Y
#
#                                       session single/multi test/train  pred  \
# 1789     091124_FiberPho_KL002Y-KL005_TimeOut        multi       test  True
# 1797     091124_FiberPho_KL007Y-KL004_TimeOut        multi       test  True
# 1863     091824_FiberPho_KL008G-KL001_TimeOut        multi       test  True
# 1955  100124_FiberPho_KL008G_KL002_2X_TimeOut        multi       test  True
# 1964     100224_FiberPho_KL002Y-KL003_TimeOut        multi       test  True
# 1988    101724_FiberPho_HF004Y_HF001R_TimeOut        multi       test  True
# 1990    101724_FiberPho_HF004Y_HF001R_TimeOut        multi       test  True
# 1993    101724_FiberPho_HF008Y_HF002G_TimeOut        multi       test  True
# 1998    101824_FiberPho_HF006G_HF001R_TimeOut        multi       test  True
# 1999    101824_FiberPho_HF006G_HF001R_TimeOut        multi       test  True
# 2001    102124_FiberPho_HF004Y_HF006G_TimeOut        multi       test  True
# 2002    102124_FiberPho_HF004Y_HF006G_TimeOut        multi       test  True
# 2004    102124_FiberPho_HF004Y_HF006G_TimeOut        multi       test  True
# 2005    102124_FiberPho_HF008Y_HF001R_TimeOut        multi       test  True
# 2006    102124_FiberPho_HF008Y_HF001R_TimeOut        multi       test  True
# 2007    102124_FiberPho_HF008Y_HF001R_TimeOut        multi       test  True
# 2009    102224_FiberPho_HF003B_HF001R_TimeOut        multi       test  True
#
#      color pair  initial nan   vel nan  correct  final nan  levers  mags  \
# 1789         RY     0.303413  0.350183    False       -1.0    True  True
# 1797         RY     0.336403  0.371800    False       -1.0    True  True
# 1863         GY     0.302106  0.327665    False       -1.0    True  True
# 1955         RG     0.322378  0.329199    False       -1.0    True  True
# 1964         RY     0.378770  0.415975    False       -1.0    True  True
# 1988         RY     0.377070  0.405360    False       -1.0    True  True
# 1990         YB     0.325736  0.347727    False       -1.0    True  True
# 1993         GY     0.393805  0.416129    False       -1.0    True  True
# 1998         RG     0.509456  0.522460    False       -1.0    True  True
# 1999         GY     0.601449  0.615440    False       -1.0    True  True
# 2001         YB     0.778844  0.786516    False       -1.0    True  True
# 2002         YB     0.740101  0.750513    False       -1.0    True  True
# 2004         GY     0.766814  0.770453    False       -1.0    True  True
# 2005         GY     0.730069  0.737884    False       -1.0    True  True
# 2006         GY     0.724094  0.737771    False       -1.0    True  True
# 2007         RY     0.789407  0.793372    False       -1.0    True  True
# 2009         YB     0.687186  0.704425    False       -1.0    True  True
#
#      trial type familiarity  fiber pho
# 1789       coop          UF       True
# 1797       coop          UF       True
# 1863       coop          UF       True
# 1955       coop          UF       True
# 1964       coop          UF       True
# 1988       coop          UF       True
# 1990       coop          TP       True
# 1993       coop          UF       True
# 1998       coop          UF       True
# 1999       coop          TP       True
# 2001       coop          TP       True
# 2002       coop          TP       True
# 2004       coop          UF       True
# 2005       coop          TP       True
# 2006       coop          TP       True
# 2007       coop          UF       True
# 2009       coop          TP       True

# %%
both
# Out:
#                                          vid  \
# 1895   092524_Cam2_TrNum8_Coop_KL006G-KL002B
# 1923  092724_Cam1_TrNum15_Coop_KL008G-KL008B
# 1949  100124_Cam2_TrNum15_Coop_KL004G-KL005B
# 1971   100224_Cam1_TrNum8_Coop_KL006G-KL008B
# 1992   101724_Cam1_TrNum7_Coop_HF008Y-HF006G
# 1994   101724_Cam1_TrNum4_Coop_HF008Y-HF006G
# 2000   101824_Cam2_TrNum7_Coop_KL006G-KL008Y
#
#                                       session single/multi test/train   pred  \
# 1895  092524_FiberPho_KL006G-KL002_2X_TimeOut        multi       test  False
# 1923     092724_FiberPho_KL008G_KL002_TimeOut        multi       test  False
# 1949  100124_FiberPho_KL004G-KL001_2X_TimeOut        multi       test  False
# 1971     100224_FiberPho_KL006G-KL008_TimeOut        multi       test  False
# 1992    101724_FiberPho_HF008Y_HF002G_TimeOut        multi       test   True
# 1994    101724_FiberPho_HF008Y_HF002G_TimeOut        multi       test   True
# 2000    101824_FiberPho_HF006G_HF001R_TimeOut        multi       test   True
#
#      color pair  initial nan   vel nan  correct  final nan  levers   mags  \
# 1895         GB    -1.000000 -1.000000    False       -1.0    True  False
# 1923         GB    -1.000000 -1.000000    False       -1.0    True  False
# 1949         GB    -1.000000 -1.000000    False       -1.0   False  False
# 1971         GB    -1.000000 -1.000000    False       -1.0   False  False
# 1992         GY     0.578299  0.598225    False       -1.0    True  False
# 1994         GY     0.443932  0.460793    False       -1.0    True  False
# 2000         GY     0.608958  0.617554    False       -1.0   False  False
#
#      trial type familiarity  fiber pho
# 1895       coop          UF       True
# 1923       coop          TP       True
# 1949       coop          UF       True
# 1971       coop          UF       True
# 1992       coop          TP       True
# 1994       coop          TP       True
# 2000       coop          TP       True

# %%
no_pred.to_csv('GB_fiber_pho_vids.csv', index=False)

# %%
check_df = preds.df[((preds.df['levers'] == False) | (preds.df['mags'] == False)) & (preds.df['trial type'] == 'coop')]

# %%
check_df
# Out:
#                                                     vid  \
# 1428             050324_Cam4_TrNum12_Coop_KL001B-KL001Y
# 1429              050324_Cam4_TrNum5_Coop_KL001B-KL001Y
# 1541              051324_Cam1_TrNum7_Coop_EB001R-EB033Y
# 1773              091024_Cam2_TrNum8_Coop_KL008G-KL005B
# 1778             091024_Cam2_TrNum12_Coop_KL008G-KL005Y
# 1779             091024_Cam2_TrNum10_Coop_KL008G-KL008B
# 1884             092424_Cam2_TrNum12_Coop_KL005Y-KL008B
# 1895              092524_Cam2_TrNum8_Coop_KL006G-KL002B
# 1923             092724_Cam1_TrNum15_Coop_KL008G-KL008B
# 1949             100124_Cam2_TrNum15_Coop_KL004G-KL005B
# 1971              100224_Cam1_TrNum8_Coop_KL006G-KL008B
# 1992              101724_Cam1_TrNum7_Coop_HF008Y-HF006G
# 1994              101724_Cam1_TrNum4_Coop_HF008Y-HF006G
# 2000              101824_Cam2_TrNum7_Coop_KL006G-KL008Y
# 2077  041224_COOPTRAIN_LARGEARENA_EB009B-EB019Y_Camera4
# 2081  041224_COOPTRAIN_LARGEARENA_EB031B-EB033Y_Camera3
# 2086  041424_COOPTRAIN_LARGEARENA_EB009B-EB019Y_Camera2
# 2092  041524_COOPTRAIN_LARGEARENA_EB027Y-EB029R_Camera4
# 2109  041824_COOPTRAIN_LARGEARENA_EB009B-EB033Y_Camera3
# 2113  041824_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2119  041924_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2122  042224_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2131  042324_COOPTRAIN_LARGEARENA_EB003B-EB019Y_Camera2
# 2134  042324_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2140  042424_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2146  042524_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2147  042524_COOPTRAIN_LARGEARENA_EB009B-EB033Y_Camera3
# 2148  042524_COOPTRAIN_LARGEARENA_EB003B-EB019Y_Camera2
# 2151  042624_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2153  042924_COOPTRAIN_LARGEARENA_EB005Y-EB007R_Camera1
# 2154  042924_COOPTRAIN_LARGEARENA_EB021R-EB023B_Camera3
# 2155  042924_COOPTRAIN_LARGEARENA_EB027Y-EB029R_Camera4
# 2156  042924_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2159  043024_COOPTRAIN_LARGEARENA_EEB001R-EB031B_Cam...
# 2181  071024_COOPTRAIN_LARGEARENA_HF006G-HF008Y.txt_...
# 2184  071124_COOPTRAIN_LARGEARENA_HF003B-HF004Y.txt_...
# 2185  071124_COOPTRAIN_LARGEARENA_HF006G-HF008Y.txt_...
#
#                                       session single/multi test/train   pred  \
# 1428         050324_KL001_TimeOut_Translucent        multi       test   True
# 1429         050324_KL001_TimeOut_Translucent        multi       test   True
# 1541      051324_EB001R-031B-033Y_TimeOut_VEH        multi       test   True
# 1773     091024_FiberPho_KL007Y-KL002_TimeOut        multi       test  False
# 1778     091024_FiberPho_KL007Y-KL002_TimeOut        multi       test  False
# 1779     091024_FiberPho_KL007Y-KL002_TimeOut        multi       test  False
# 1884     092424_FiberPho_KL005Y-KL008_TimeOut        multi       test   True
# 1895  092524_FiberPho_KL006G-KL002_2X_TimeOut        multi       test  False
# 1923     092724_FiberPho_KL008G_KL002_TimeOut        multi       test  False
# 1949  100124_FiberPho_KL004G-KL001_2X_TimeOut        multi       test  False
# 1971     100224_FiberPho_KL006G-KL008_TimeOut        multi       test  False
# 1992    101724_FiberPho_HF008Y_HF002G_TimeOut        multi       test   True
# 1994    101724_FiberPho_HF008Y_HF002G_TimeOut        multi       test   True
# 2000    101824_FiberPho_HF006G_HF001R_TimeOut        multi       test   True
# 2077                                   041224        multi      train   True
# 2081                                   041224        multi      train   True
# 2086                                   041424        multi      train   True
# 2092                                   041524        multi      train   True
# 2109                                   041824        multi      train   True
# 2113                                   041824        multi      train   True
# 2119                                   041924        multi      train   True
# 2122                                   042224        multi      train   True
# 2131                                   042324        multi      train   True
# 2134                                   042324        multi      train   True
# 2140                                   042424        multi      train   True
# 2146                                   042524        multi      train   True
# 2147                                   042524        multi      train   True
# 2148                                   042524        multi      train   True
# 2151                                   042624        multi      train   True
# 2153                                   042924        multi      train   True
# 2154                                   042924        multi      train   True
# 2155                                   042924        multi      train   True
# 2156                                   042924        multi      train   True
# 2159                                   043024        multi      train   True
# 2181                                   071024        multi      train   True
# 2184                                   071124        multi      train   True
# 2185                                   071124        multi      train   True
#
#      color pair  initial nan   vel nan  correct  final nan  levers   mags  \
# 1428         YB     0.419153  0.436394    False  -1.000000   False  False
# 1429         YB     0.372370  0.398114    False  -1.000000   False  False
# 1541         RY     0.275847  0.281242     True   0.010783    True  False
# 1773         GB    -1.000000 -1.000000    False  -1.000000   False  False
# 1778         GY    -1.000000 -1.000000    False  -1.000000   False  False
# 1779         GB    -1.000000 -1.000000    False  -1.000000   False  False
# 1884         YB     0.134125  0.143235     True   0.003409   False  False
# 1895         GB    -1.000000 -1.000000    False  -1.000000    True  False
# 1923         GB    -1.000000 -1.000000    False  -1.000000    True  False
# 1949         GB    -1.000000 -1.000000    False  -1.000000   False  False
# 1971         GB    -1.000000 -1.000000    False  -1.000000   False  False
# 1992         GY     0.578299  0.598225    False  -1.000000    True  False
# 1994         GY     0.443932  0.460793    False  -1.000000    True  False
# 2000         GY     0.608958  0.617554    False  -1.000000   False  False
# 2077         YB     0.362437  0.389857    False  -1.000000    True  False
# 2081         YB     0.172015  0.178020     True   0.004061    True  False
# 2086         YB     0.303040  0.317648    False  -1.000000    True  False
# 2092         RY     0.173578  0.186327     True   0.004222    True  False
# 2109         YB     0.117830  0.126639     True   0.002947    True  False
# 2113         RB     0.102146  0.103417     True   0.002089   False  False
# 2119         RB     0.100301  0.101062     True   0.001802   False  False
# 2122         RB     0.086969  0.087676     True   0.001630   False  False
# 2131         YB     0.198268  0.206560     True   0.003944    True  False
# 2134         RB     0.088729  0.089464     True   0.002024   False  False
# 2140         RB     0.098025  0.099152     True   0.001812   False  False
# 2146         RB     0.084590  0.085219     True   0.001795   False  False
# 2147         YB     0.124399  0.128747     True   0.002705    True  False
# 2148         YB     0.223128  0.232697     True   0.004455    True  False
# 2151         RB     0.079549  0.080170     True   0.001132   False  False
# 2153         RY     0.178387  0.190292     True   0.003185   False  False
# 2154         RB     0.061741  0.063743     True   0.001046   False  False
# 2155         RY     0.210156  0.224767     True   0.004640   False  False
# 2156         RB     0.091693  0.092439     True   0.001270   False  False
# 2159         RB     0.061309  0.061650     True   0.000674   False  False
# 2181         GY     0.448872  0.487018    False  -1.000000   False  False
# 2184         YB     0.495339  0.545504    False  -1.000000   False  False
# 2185         GY     0.431885  0.475965    False  -1.000000   False  False
#
#      trial type familiarity  fiber pho
# 1428       coop         NaN      False
# 1429       coop         NaN      False
# 1541       coop          UF      False
# 1773       coop         NaN      False
# 1778       coop         NaN      False
# 1779       coop         NaN      False
# 1884       coop          UF       True
# 1895       coop          UF       True
# 1923       coop          TP       True
# 1949       coop          UF       True
# 1971       coop          UF       True
# 1992       coop          TP       True
# 1994       coop          TP       True
# 2000       coop          TP       True
# 2077       coop         NaN      False
# 2081       coop         NaN      False
# 2086       coop         NaN      False
# 2092       coop         NaN      False
# 2109       coop         NaN      False
# 2113       coop         NaN      False
# 2119       coop         NaN      False
# 2122       coop         NaN      False
# 2131       coop         NaN      False
# 2134       coop         NaN      False
# 2140       coop         NaN      False
# 2146       coop         NaN      False
# 2147       coop         NaN      False
# 2148       coop         NaN      False
# 2151       coop         NaN      False
# 2153       coop         NaN      False
# 2154       coop         NaN      False
# 2155       coop         NaN      False
# 2156       coop         NaN      False
# 2159       coop         NaN      False
# 2181       coop         NaN      False
# 2184       coop         NaN      False
# 2185       coop         NaN      False
