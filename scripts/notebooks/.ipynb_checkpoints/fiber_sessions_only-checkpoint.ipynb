# %%
import numpy as np
import pandas as pd 
import os 
import matplotlib.pyplot as plt
import h5py
import tqdm

# %%
root = '/gpfs/radev/pi/saxena/aj764/' 
# only going to do instrumental and cooperation videos right now

# %%
df = pd.DataFrame(columns=['directory', 'session', 'vid', 'video type', 'color type', 'preds', 'error', 'lever', 'mag', 'event id', 'neuronal'])
# for paired testing sessions
dircs = ['PairedTestingSessions', 'Training_COOP_Fiber']
d = dircs[0]
sessions = os.listdir(f'{root}/{d}')
for s in tqdm.tqdm(sessions): 
    if 'FiberPho' in s:
        vids = os.listdir(f'{root}/{d}/{s}/Videos/')
        for v in vids:
            if 'Coop' in v or 'IS' in v:
                video_type = 'Coop' if 'Coop' in v else 'IS'
                name = v.split('.')[0]
                date = name.split('_')[0]
                color_type = 'dyed' if (int(date[-2:]) == 24 and int(date[:2]) < 11) else 'collar'
                preds = os.path.exists(f'{root}/{d}/{s}/Tracking/slp/{name}.predictions.slp')
                if preds:
                    with h5py.File(f'{root}/{d}/{s}/Tracking/h5/{name}.predictions.h5','r') as f:
                        locations = f["tracks"][:].T
                    error = np.sum(np.isnan(locations)) / np.prod(locations.shape)
                else:
                    error = np.nan
                lever = os.path.exists(f'{root}/{d}/{s}/Behavioral/processed/lever/{name}_lever.csv')
                mag = os.path.exists(f'{root}/{d}/{s}/Behavioral/processed/mag/{name}_mag.csv')
                if lever:
                    levs = pd.read_csv(f'{root}/{d}/{s}/Behavioral/processed/lever/{name}_lever.csv')
                    event_id = 'RatID' in levs.columns.tolist()
                else:
                    event_id = False
                neuronal = os.path.exists(f'{root}/{d}/{s}/Neuronal/{name}.mat')
                # ['directory', 'session', 'vid', 'video type', 'color type', 'preds', 'error', 'lever', 'mag', 'event id', 'neuronal']
                if neuronal:
                    df.loc[len(df)] = [d, s, v, video_type, color_type, preds, error, lever, mag, event_id, neuronal]
# Out:
# 100%|██████████| 230/230 [00:04<00:00, 53.51it/s]

# %%
d = dircs[1]
sessions = os.listdir(f'{root}/{d}')
for s in tqdm.tqdm(sessions): 
    vids = os.listdir(f'{root}/{d}/{s}/')
    vids = [x for x in vids if 'mp4' in x]
    for v in vids:
        video_type = 'Coop'
        name = v.split('.')[0]
        date = name.split('_')[0]
        color_type = 'dyed' if (int(date[-2:]) == 24 and int(date[:2]) < 11) else 'collar'
        preds = os.path.exists(f'{root}/{d}/{s}/{name}.h5')
        if preds:
            with h5py.File(f'{root}/{d}/{s}/{name}.h5','r') as f:
                locations = f["tracks"][:].T
            error = np.sum(np.isnan(locations)) / np.prod(locations.shape)
        else:
            error = np.nan 
        lever = False
        mag = False
        event_id = False
        name = '_'.join(name.split('_')[:-1])
        neuronal = os.path.exists(f'{root}/{d}/{s}/{name}.mat')
        # ['directory', 'session', 'vid', 'video type', 'color type', 'preds', 'error', 'lever', 'mag', 'event id', 'neuronal']
        if neuronal:
            df.loc[len(df)] = [d, s, v, video_type, color_type, preds, error, lever, mag, event_id, neuronal]
# Out:
# 100%|██████████| 280/280 [00:01<00:00, 140.54it/s]

# %%
df.shape
# Out:
# (462, 11)

# %%
coop = df[df['video type'] == 'Coop']
inst =  df[df['video type'] == 'IS']

# %%
df
# Out:
#                  directory                                            session  \
# 0    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# 1    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# 2    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# 3    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# 4    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# ..                     ...                                                ...
# 457    Training_COOP_Fiber  062325_COOPTRAIN_LARGEARENA_FIBER_KF025Y-KF024...
# 458    Training_COOP_Fiber  060925_COOPTRAIN_LARGEARENA_KF025B-KF024R_Sess...
# 459    Training_COOP_Fiber  060625_COOPTRAIN_LARGEARENA_KM022B-KM027R_Sess...
# 460    Training_COOP_Fiber  062325_COOPTRAIN_LARGEARENA_FIBER_KF026R-KF025...
# 461    Training_COOP_Fiber  060425_COOPTRAIN_LARGEARENA_KF024R-KF025B_Sess...
#
#                                                    vid video type color type  \
# 0           090924_Cam1_TrNum10_Coop_KL007G-KL002Y.mp4       Coop       dyed
# 1           090924_Cam1_TrNum14_Coop_KL007G-KL002B.mp4       Coop       dyed
# 2            090924_Cam1_TrNum8_Coop_KL007G-KL007Y.mp4       Coop       dyed
# 3                     090924_Cam1_TrNum7_IS_KL007G.mp4         IS       dyed
# 4                    090924_Cam1_TrNum15_IS_KL007G.mp4         IS       dyed
# ..                                                 ...        ...        ...
# 457  062325_COOPTRAIN_LARGEARENA_FIBER_KF025Y-KF024...       Coop     collar
# 458  060925_COOPTRAIN_LARGEARENA_KF025B-KF024R_Sess...       Coop     collar
# 459  060625_COOPTRAIN_LARGEARENA_KM022B-KM027R_Sess...       Coop     collar
# 460  062325_COOPTRAIN_LARGEARENA_FIBER_KF026R-KF025...       Coop     collar
# 461  060425_COOPTRAIN_LARGEARENA_KF024R-KF025B_Sess...       Coop     collar
#
#      preds     error  lever    mag  event id  neuronal
# 0     True  0.001136   True   True      True      True
# 1    False       NaN   True   True     False      True
# 2     True  0.001235   True   True      True      True
# 3     True  0.006277  False  False     False      True
# 4     True  0.007022  False  False     False      True
# ..     ...       ...    ...    ...       ...       ...
# 457  False       NaN  False  False     False      True
# 458  False       NaN  False  False     False      True
# 459  False       NaN  False  False     False      True
# 460  False       NaN  False  False     False      True
# 461  False       NaN  False  False     False      True
#
# [462 rows x 11 columns]

# %%
good_fiber = coop[coop['preds'] & coop['lever'] & coop['mag'] & coop['event id'] & (coop['error'] < .2)] # basically useable fiber pho videos in paired testing sessions

# %%
good_fiber.to_csv('good_fiber_videos.csv', index=False)

# %%
df[df['video type'] == 'Coop'].shape[0], df[df['video type'] == 'IS'].shape[0]
# Out:
# (384, 78)

# %%
384+78
# Out:
# 462

# %%
df[(df['directory'] == 'Training_COOP_Fiber') & df['preds']]
# Out:
#                directory                                            session  \
# 189  Training_COOP_Fiber  062425_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...
# 195  Training_COOP_Fiber  061825_COOPTRAIN_LARGEARENA_FIBER_KM018B-KM018...
# 199  Training_COOP_Fiber  062625_COOPTRAIN_LARGEARENA_FIBER_KF018Y-KF018...
# 202  Training_COOP_Fiber  062625_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...
# 205  Training_COOP_Fiber  062025_COOPTRAIN_LARGEARENA_FIBER_KM018Y-KM018...
# ..                   ...                                                ...
# 441  Training_COOP_Fiber  061325_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...
# 445  Training_COOP_Fiber  060325_COOPTRAIN_LARGEARENA_KM017G-KM017R_Sess...
# 450  Training_COOP_Fiber  060625_COOPTRAIN_LARGEARENA_KM018Y-KM018B_Sess...
# 454  Training_COOP_Fiber  060625_COOPTRAIN_LARGEARENA_KM018B-KM018Y_Sess...
# 455  Training_COOP_Fiber  061625_COOPTRAIN_LARGEARENA_FIBER_KM018Y-KM018...
#
#                                                    vid video type color type  \
# 189  062425_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...       Coop     collar
# 195  061825_COOPTRAIN_LARGEARENA_FIBER_KM018B-KM018...       Coop     collar
# 199  062625_COOPTRAIN_LARGEARENA_FIBER_KF018Y-KF018...       Coop     collar
# 202  062625_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...       Coop     collar
# 205  062025_COOPTRAIN_LARGEARENA_FIBER_KM018Y-KM018...       Coop     collar
# ..                                                 ...        ...        ...
# 441  061325_COOPTRAIN_LARGEARENA_FIBER_KM017G-KM017...       Coop     collar
# 445  060325_COOPTRAIN_LARGEARENA_KM017G-KM017R_Sess...       Coop     collar
# 450  060625_COOPTRAIN_LARGEARENA_KM018Y-KM018B_Sess...       Coop     collar
# 454  060625_COOPTRAIN_LARGEARENA_KM018B-KM018Y_Sess...       Coop     collar
# 455  061625_COOPTRAIN_LARGEARENA_FIBER_KM018Y-KM018...       Coop     collar
#
#      preds     error  lever    mag  event id  neuronal
# 189   True  0.345030  False  False     False      True
# 195   True  0.491309  False  False     False      True
# 199   True  0.447788  False  False     False      True
# 202   True  0.143289  False  False     False      True
# 205   True  0.535664  False  False     False      True
# ..     ...       ...    ...    ...       ...       ...
# 441   True  0.382752  False  False     False      True
# 445   True  0.565833  False  False     False      True
# 450   True  0.416581  False  False     False      True
# 454   True  0.425776  False  False     False      True
# 455   True  0.455975  False  False     False      True
#
# [78 rows x 11 columns]

# %%
df
# Out:
#                  directory                                            session  \
# 0    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# 1    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# 2    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# 3    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# 4    PairedTestingSessions               090924_FiberPho_KL007G-KL002_TimeOut
# ..                     ...                                                ...
# 457    Training_COOP_Fiber  062325_COOPTRAIN_LARGEARENA_FIBER_KF025Y-KF024...
# 458    Training_COOP_Fiber  060925_COOPTRAIN_LARGEARENA_KF025B-KF024R_Sess...
# 459    Training_COOP_Fiber  060625_COOPTRAIN_LARGEARENA_KM022B-KM027R_Sess...
# 460    Training_COOP_Fiber  062325_COOPTRAIN_LARGEARENA_FIBER_KF026R-KF025...
# 461    Training_COOP_Fiber  060425_COOPTRAIN_LARGEARENA_KF024R-KF025B_Sess...
#
#                                                    vid video type color type  \
# 0           090924_Cam1_TrNum10_Coop_KL007G-KL002Y.mp4       Coop       dyed
# 1           090924_Cam1_TrNum14_Coop_KL007G-KL002B.mp4       Coop       dyed
# 2            090924_Cam1_TrNum8_Coop_KL007G-KL007Y.mp4       Coop       dyed
# 3                     090924_Cam1_TrNum7_IS_KL007G.mp4         IS       dyed
# 4                    090924_Cam1_TrNum15_IS_KL007G.mp4         IS       dyed
# ..                                                 ...        ...        ...
# 457  062325_COOPTRAIN_LARGEARENA_FIBER_KF025Y-KF024...       Coop     collar
# 458  060925_COOPTRAIN_LARGEARENA_KF025B-KF024R_Sess...       Coop     collar
# 459  060625_COOPTRAIN_LARGEARENA_KM022B-KM027R_Sess...       Coop     collar
# 460  062325_COOPTRAIN_LARGEARENA_FIBER_KF026R-KF025...       Coop     collar
# 461  060425_COOPTRAIN_LARGEARENA_KF024R-KF025B_Sess...       Coop     collar
#
#      preds     error  lever    mag  event id  neuronal
# 0     True  0.001136   True   True      True      True
# 1    False       NaN   True   True     False      True
# 2     True  0.001235   True   True      True      True
# 3     True  0.006277  False  False     False      True
# 4     True  0.007022  False  False     False      True
# ..     ...       ...    ...    ...       ...       ...
# 457  False       NaN  False  False     False      True
# 458  False       NaN  False  False     False      True
# 459  False       NaN  False  False     False      True
# 460  False       NaN  False  False     False      True
# 461  False       NaN  False  False     False      True
#
# [462 rows x 11 columns]

# %%
import h5py
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
vids = os.listdir('/gpfs/radev/pi/saxena/aj764/fiber_videos/pts/Tracking/h5')

# %%
vids

# %%
for vid in vids:
    with h5py.File('/gpfs/radev/pi/saxena/aj764/fiber_videos/pts/Tracking/h5/' + vid,'r') as f:
        locations = f["tracks"][:].T
    nan = np.sum(np.isnan(locations)) / np.prod(locations.shape)
    with h5py.File('/gpfs/radev/pi/saxena/aj764/fiber_videos/pts/Tracking_II/h5/' + vid,'r') as f:
        locations = f["tracks"][:].T
    nan_II = np.sum(np.isnan(locations)) / np.prod(locations.shape)
    plt.plot(nan, nan_II, '.')
x = np.arange(.5, 1, .01)
plt.plot(x, x, 'k', linestyle='dashed')
